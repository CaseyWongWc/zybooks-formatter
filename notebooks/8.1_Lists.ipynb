# %% [markdown]
# ## 8.1 Lists
#
# ### List basics
#
# The list object type is one of the most important and often-used types in Python. Two terms that are used to define a list are container and mutable. A container is an object that groups related objects together. A list is a mutable container, meaning the size of the list can grow or shrink and elements within the list can change.  A list is also a sequence; thus, the contained objects maintain a left-to-right positional order. Elements of the list can be accessed via indexing operations that specify the position of the desired element in the list. Each element in a list can be a different object type such as strings, integers, floats, or even other lists.
#
# The animation below illustrates how a list is created using brackets `[]` around the list elements.  The animation also shows how a list object contains references to the contained objects.
#
# ### PARTICIPATION ACTIVITY: Lists contain references to other objects.
#
# An empty container representing the command line.
#
# The user creates a new list.
# A line of code, my*list = ["hello", -4.2, 5], appears in the command line.
# The line of code, my*list = ["hello", -4.2, 5], is sent to the Python interpreter.
# An empty container with 4 cells is created.
# The first cell is filled with my_list.
#
# The interpreter creates a new object for each list element.
# The second cell is filled with "hello".
# The third cell is filled with -4.2.
# The fourth cell is filled with 5.
#
# "my*list" holds references to objects in the list.
# Next to my*list in the first cell, are the references 0, 1, and 2.
#
# A list can also be created using the built-in list() function. The list() function accepts a single iterable object argument, such as a string, list, or tuple, and returns a new list object. Ex: `list("abc")` creates a new list with the elements ["a", "b", "c"].
#
# ### PARTICIPATION ACTIVITY: List basics.
#
# **1.** A program can modify the elements of an existing list.
#
# **2.** The size of a list is determined when the list is created and cannot change.
#
# **3.** All elements of a list must have the same type.
#
# ### Accessing list elements
#
# An index is a zero-based integer matching to a specific position in the list's sequence of elements. A programmer can reference a specific element in a list by providing an index. Ex: `my_list[4]` uses an integer to access the element at index 4 (the 5th element) of my_list.
#
# An index can also be an expression, as long as that expression evaluates into an integer. Replacing the index with an integer variable, such as in `my_list[i]`, allows the programmer to quickly and easily lookup the (i+1)th  element in a list.
#
# ### LAB ACTIVITY: List's ith element can be directly accessed using [i]: Oldest people program.
#
# Consider the following program that allows a user to print the age of the Nth oldest known person to have ever lived. Note: The ages are in a list sorted from oldest to youngest.
#
#  1. Modify the program to print the correct ordinal number ("1st", "2nd", "3rd", "4th", or "5th") instead of "1th", "2th", "3th", "4th", or "5th".
#
# 1. For the oldest person, remove the ordinal number (1st) from the print statement to say, "The oldest person lived 122 years".
#
# Reminder: List indices begin at 0, not 1, thus the print statement uses oldest*people[nth*person - 1], to access the nth_person element (element 1 at index 0, element 2 at index 1, etc.).
#
# The program can quickly access the Nth oldest person's age using `oldest_people[nth_person-1]`. Note that the index is `nth_person-1` rather than just nth_person because a list's indices start at 0, so the first age is at index 0, the second at index 1, etc.
#
# A list's index must be an integer type. The index cannot be a floating-point type, even if the value is 0.0, 1.0, etc.
#
# ### PARTICIPATION ACTIVITY: List indices.
#
# **1.** `print(animals[0])`
# Answer: cat
# *Hint: Index 0 references the first element in the list.*
# *Indices are 0-based integers, so index 0 references the first element in animals, or "cat".*
#
# **2.** `print(animals[2])`
# Answer: bird
# *Hint: Index 2 references the third element in the list.*
# *Indices are 0-based integers, so index 2 references the third element in animals, or "bird".*
#
# **3.** `print(animals[0 + 1])`
# Answer: dog
# *Hint: An index can be an expression. In this case, the expression evaluates to 1, which references the second element in the list.*
# *An index can be an expression as long as that expression evaluates to an integer. 0 + 1 = 1, and the second element (index 1) is "dog".*
#
# **4.** i = 3
# print(animals[i])
# Answer: raptor
# *Hint: An index can be an expression. In this case, the expression evaluates to the value of i, or 3, which references the fourth element in the list.*
# *An index can be an expression as long as that expression evaluates to an integer. i == 3, and the fourth element (index 3) is "raptor".*
#
# ### Common list operations and in-place list modification
#
# The following table includes common operations performed on lists including creating lists, accessing list elements, slicing, and concatenation. Some of the operations might be familiar as sequence type operations also supported by strings. Note that slicing a list and concatenating two lists will return a new list.
#
# Unlike the string sequence type, a list is mutable, meaning a list can grow and shrink without replacing the entire list with an updated copy. Such growing and shrinking capability is called in-place modification.  The dark-shaded rows highlight in-place modification operations.
#
# > **Some common list operations.**
# > | Operation | Description | Example code | Example output |
# > | --- | --- | --- | --- |
# > | my*list = [1, 2, 3] | Creates a list. | my*list = [1, 2, 3] print(my*list) | `[1, 2, 3]` |
# > | list(iter) | Creates a list. | my*list = list("123") print(my*list) | `['1', '2', '3']` |
# > | my*list[index] | Gets an element from a list. | my*list = [1, 2, 3] print(my*list[1]) | `2` |
# > | my*list[start:end] | Gets a new list containing some of another list's elements. | my*list = [1, 2, 3] print(my*list[1:3]) | `[2, 3]` |
# > | my*list1 + my*list2 | Gets a new list with elements of my*list2 added to end of my*list1. | my*list = [1, 2] + [3]  print(my*list) | `[1, 2, 3]` |
# > | my*list[i] = x | Changes the value of the element at index i in-place. | my*list = [1, 2, 3] my*list[2] = 9  print(my*list) | `[1, 2, 9]` |
# > | del my*list[i] | Deletes the element from index i from a list. | my*list = [1, 2, 3] del my*list[1] print(my_list) | `[1, 3]` |
#
# The below animation illustrates how a program can use in-place modifications to modify the contents of a list.
#
# ### PARTICIPATION ACTIVITY: In-place modification of a list using indexing.
#
# colors = ["red", "green", "blue"]
#
# colors[1] = "yellow"  # Change list element
# print(colors)
#
# fav*color = colors[2]  # Bind to "blue"
# fav*color = "turquoise"  # List not altered
# print(colors)
#
# A list can be modified in place by assigning a specific list index with a new value.
# The line of code, colors = ["red", "green", "blue"], executes.
# A list is created named colors.
# At index 0 is the string "red".
# At index 1 is the string "green".
# At index 2 is the string "blue".
# The line of code, colors[1] = "yellow"  # Change list element, executes.
# Index 1 of the list colors now contains the string "yellow".
# The line of code, print(colors), executes.
# ['red', 'green', 'blue'] is output.
#
# Assigning a variable with an element of an existing list, and then reassigning that variable with a different value does not modify the list.
# The line of code, fav*color = colors[2]  # Bind to "blue", executes.
# A variable fav*color is created and points to "blue".
# The line of code, fav*color = "turquoise"  # List not altered, executes.
# The variable fav*color now equals "turquioise".
#
# The difference between in-place modification of a list and an operation that creates an entirely new list is important. In-place modification affects any variable that references the list and can have unintended side effects. Consider the following code in which the variables your*teams and my*teams reference the same list (via the assignment `your_teams = my_teams`). If either your*teams or my*teams modifies an element of the list, then the change is reflected in the other variable as well.
#
# The below Python Tutor tool executes a Python program and visually shows the objects and variables of a program. The tool shows names of variables on the left, with arrows connecting to bound objects on the right. Note that the tool does not show each number or string character as unique objects to improve clarity. The Python Tutor tool is available at www.pythontutor.com.
#
# **PythonTutor: In-place modification of a list.**

# %%
my_teams = ["Raptors", "Heat", "Nets"]
your_teams = my_teams  # Create a shared reference to same list

my_teams[1] = "Lakers"  # Modify list element

print(f"My teams are: {my_teams}") # Both variables have changed
print(f"Your teams are: {your_teams}")  # Both variables have changed

# %% [markdown]
# - Assigning your*teams with my*teamspoints both names at the same list object.
#     - Modifying the second element of my*teams also affects your*teams, since both names point to the same list

# %%
my_teams = ["Raptors", "Heat", "Nets"]
your_teams = my_teams  # Create a shared reference to same list

my_teams[1] = "Lakers"  # Modify list element

print(f"My teams are: {my_teams}")  # Both variables have changed
print(f"Your teams are: {your_teams}")  # Both variables have changed

# %% [markdown]
# In the above example, changing the elements of my*teams also affects the contents of your*teams. The change occurs because my*teams and your*teams are bound to the same list object. The code `my_teams[1] = "Lakers"` modifies the element in position 1 of the shared list object, thus changing the value of both my*teams[1] and your*teams[1].
#
# The programmer of the above example probably meant to only change my*teams. The correct approach would have been to create a *copy* of the list instead. One simple method to create a copy is to use slice notation with no start or end indices, as in `your*teams = my_teams[:]`.
#
# **PythonTutor: In-place modification of a copy of a list.**

# %%
my_teams = ["Raptors", "Heat", "Nets"]
your_teams = my_teams[:]  # Assign your_teams with a COPY of my_teams

my_teams[1] = "Lakers"  # Modify list element

print(f"My teams are: {my_teams}")  # Both variables have changed
print(f"Your teams are: {your_teams}")  # Both variables have changed

# %% [markdown]
# - Using slicing [:] creates a copy of my*teams and assigns your*teams with the copy.
#     - Modifying my*teams does not impact your*teams copy.

# %%
my_teams = ["Raptors", "Heat", "Nets"]
your_teams = my_teams[:]  # Assign your_teams with a COPY of my_teams

my_teams[1] = "Lakers"  # Modify list element

print(f"My teams are: {my_teams}")  # List element has changed
print(f"Your teams are: {your_teams}")  # List element has not changed

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Common list operations.
#
# **1.** Which statement deletes the third element from a list called my_list?
#
# **2.** Which operation does not perform an in-place modification?
#
# **3.** Which statement creates a copy of a list?
#
# ### CHALLENGE ACTIVITY: Enter the output for the list.
#
# **Level 1:**
#
# What is the output?

# %%
user_values = [1, 4, 7]

print(user_values)

# %% [markdown]
# *`user_values = [{{firstElement}}, {{secondElement}}, {{thirdElement}}]` declares a list with three elements.*
#
# **Level 2:**
#
# What is the output?

# %%
user_values = [1, 5, 7]
user_values[{{toChange.value}}] = user_values[{{toChange.value}}] + 1

print(user_values)

# %% [markdown]
# *`user_values[{{toChange.value}}] = user_values[{{toChange.value}}] + 1` increments the {{toChange.order}} element in user_values by 1.*
#
# **Level 3:**
#
# What is the output?

# %%
user_values = [1, 5, 7]
user_values[{{toChange.lineOne}}] = user_values[{{toChange.lineOne}}] + 1
user_values[{{toChange.lineTwo}}] = user_values[{{toChange.lineTwo}}] + 2

print(user_values)

# %% [markdown]
# *`user_values[{{toChange.lineTwo}}] = user_values[{{toChange.lineTwo}}] + 2` increments the {{toChange.word}} element in user_values by 2.*
#
# **Level 4:**
#
# What is the output?

# %%
user_values = [1, 4, 7]
user_values[{{toChange.value}}] = user_values[{{toChange.toAccess.value}}]

print(user_values)

# %% [markdown]
# *`user_values[{{toChange.value}}] = user_values[{{toChange.toAccess.value}}]` assigns the {{toChange.word}} element in user*values with the value of the {{toChange.toAccess.word}} element in user*values.*
#
# **Level 5:**
#
# What is the output?

# %%
user_values = [1, 4, 7]
user_values[{{toChange.firstItem}}] = user_values[{{toChange.secondItem}}]
user_values[{{toChange.secondItem}}] = user_values[{{toChange.thirdItem}}]

print(user_values)

# %% [markdown]
# *`user_values[{{toChange.firstItem}}] = user_values[{{toChange.secondItem}}]` assigns the {{toChange.firstWord}} element in user_values with the value of the {{toChange.secondWord}} element. Then, the {{toChange.secondWord}} element is assigned with the value of the {{toChange.thirdWord}} element.*
#
# ### CHALLENGE ACTIVITY: Lists. (4 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# [...]
#
# **Explanation pattern:**
# An index is a zero-based integer matching to a specific position in the list's sequence of elements.[...] Ex: For input[...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# [...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# [...]
#
# **Code structure:**

# %%
""" Your code goes here """
print(f"My favorite ___: {___}")

# %% [markdown]
# **Level 4:**
#
# **Task pattern:**
# [...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# ---
#
# ## 8.2 List methods
#
# ### Common list methods
#
# A list method can perform a useful operation on a list such as adding or removing elements, sorting, reversing, etc.
#
#  The table below shows the available list methods. Many of the methods perform in-place modification of the list contents &mdash; a  programmer should be aware that a method that modifies the list in-place changes the underlying list object, and thus may affect the value of a variable that references the object.
#
# > **Available list methods.**
# > | List method | Description | Code example | >Final my*list value |
# > | --- | --- | --- | --- |
# > | list.append(x) | Add an item to the end of list. | my*list = [5, 8]  my*list.append(16) | `[5, 8, 16]` |
# > | list.extend([x]) | Add all items in [x] to list. | my*list = [5, 8]  my*list.extend([4, 12]) | `[5, 8, 4, 12]` |
# > | list.insert(i, x) | Insert x into list before position i. | my*list = [5, 8]  my*list.insert(1, 1.7) | `[5, 1.7, 8]` |
# > | List method | Description | Code example | Final my*list value |
# > | --- | --- | --- | --- |
# > | list.remove(x) | Remove first item from list with value x. | my*list = [5, 8, 14]  my*list.remove(8) | `[5, 14]` |
# > | list.pop() | Remove and return last item in list. | my*list = [5, 8, 14]  val = my*list.pop() | `[5, 8]` |
# > | list.pop(i) | Remove and return item at position i in list. | my*list = [5, 8, 14]  val = my*list.pop(0) | `[8, 14]` |
# > | List method | Description | Code example | Final my*list value |
# > | --- | --- | --- | --- |
# > | list.sort() | Sort the items of list in-place. | my*list = [14, 5, 8]  my*list.sort() | `[5, 8, 14]` |
# > | list.reverse() | Reverse the elements of list in-place. | my*list = [14, 5, 8]  my*list.reverse() | `[8, 5, 14]` |
# > | List method | Description | Code example | Final my*list value |
# > | --- | --- | --- | --- |
# > | list.index(x) | Return index of first item in list with value x. | my*list = [5, 8, 14]  print(my*list.index(14)) | Prints "2" |
# > | list.count(x) | Count the number of times value x is in list. | my*list = [5, 8, 5, 5, 14]  print(my*list.count(5)) | Prints "3" |
#
# A  good practice is to use list methods to add and delete list elements, rather than alternative add/delete approaches. Alternative approaches include syntax such as `my_list[len(my_list):] = [val]` to add to a list, or `del my_list[0]` to remove from a list. Using a list method yields more readable code.
#
# The list.sort() and list.reverse() methods rearrange a list element's ordering, performing in-place modification of the list.
#
#  The list.index() and list.count() return information about the list and do not modify the list.
#
#  The below interactive tool shows a few of the list methods in action:
#
# ### PARTICIPATION ACTIVITY: In-place modification using list methods.
#
# vals = [1, 4, 16]
#
# vals.append(9)
# vals.insert(2, 18)
# value = vals.pop()
# vals.remove(4)
# vals.remove(55) # Error
# End code block.
#
# vals is a list containing elements 1, 4, and 16.
# A list is called vals created. Index 0 contains value 1. Index 1 contains value 2. Index 2 contains value 16.
#
# The statement vals.append(9) appends element 9 to the end of the list.
# Index 3 of vals now contains value 9.
#
# The statement vals.insert(2, 18) inserts element 18 into position 2 of the list.
# The values at index 2 and 3 are shifted to the right by one index. Value 18 is inserted to index 2.
# vals list now contains values 1, 4, 18, 16, 9.
#
# The statement vals.pop() removes the last element, 9, from the list.
# vals list now contains values 1, 4, 18, 16.
#
# The statement vals.remove(4) removes the first instance of element 4 from the list.
# Index 1 of vals contains the value 4. Element 4 is removed from the list. The elements to the right of index 1 are shifted to the left one index.
# vals list now contains values 1, 18, 16.
#
# The statement vals.remove(55) attempts to remove the first instance of element 55 from the list. The list does not contain the element 55, which causes the program to produce an error.
#
# ### LAB ACTIVITY: Amusement park ride reservation system.
#
# The following (unfinished) program implements a digital line queuing system for an amusement park ride. The system allows a rider to reserve a place in line without actually having to wait. The rider simply enters a name into a program to reserve a place. Riders that purchase  a VIP pass get to skip past the common riders up to the last VIP rider in line. VIPs board the ride first. (Considering the average wait time for a Disneyland ride is about 45 minutes (Disneyland Crowd Levels), this might be a useful program.) For this system, an employee manually selects when the ride is dispatched (thus removing the next riders from the front of the line).
#
# Complete the following program, as described above. Once finished, add the following commands:
#
#  - The rider can enter a name to find the current position in line. (Hint: Use the list.index() method.)
#  - The rider can enter a name to remove the rider from the line.
#
# ### PARTICIPATION ACTIVITY: List methods.
#
# **1.**

# %%
temps = [65, 67, 72, 75]
temps.append(77)
print(temps[-1])

# %% [markdown]
# Answer: 77
# *Hint: append() adds an element to the end of a list.*
# *append(77) adds 77 to the end of the list, temps[-1] is the last element in the list, which is now 77.*
#
# **2.**

# %%
actors = ["Pitt", "Damon"]
actors.insert(1, "Affleck")
print(actors[0], actors[1], actors[2])

# %% [markdown]
# Answer: Pitt Affleck Damon
# *Hint: The first argument of insert indicates the position to insert before the existing element. The second argument specifies the value to insert.*
# *Position 1 is the list initially is "Damon". The inserted value is placed at position 1, and "Damon" is moved to position 2.*
#
# **3.** Write the simplest two statements that first sort my_list, then remove the largest value element from the list, using list methods.
#
# **Answer:**

# %%
my_list.sort() 
my_list.pop()

# %% [markdown]
# *Hint: The sort() method rearranges the elements so that the first element is the smallest and the last element is the largest.*
# *sort() arranges the elements from smallest to largest. pop() removes the last element, which is also the largest after the list is sorted.*
#
# **4.** Write a statement that counts the number of elements of my*list that have the value 15.
# Answer: my*list.count(15)
# *Hint: Use the count() method.*
# *The count method counts the number of times the value 15 appears in a list.*
#
# ### CHALLENGE ACTIVITY: List methods. (3 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# Integer [...] is read from input, representing the number of [...]s to be read next. Read the remaining [...]s from input and [...]
#
# **Explanation pattern:**
# One approach is to use a loop that iterates [...] times. In each iteration: [...]
#
# **Code structure:**

# %%
___ = int(input())

___ = []
""" Your code goes here """
print(___)

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# Lists [...] and [...] are read from input, representing passengers waiting to board a bus and passengers on the bus, respectively. [...] Perform the following tasks: [...] Note: All passenger names are unique.
#
# **Explanation pattern:**
# [...] [...]
#
# **Code structure:**

# %%
___ = input().split()
___ = input().split()
___
print(f"Passengers waiting at a bus stop: {___}")
print(f"Passengers on board: {___}")
""" Your code goes here """
print(f"Updated passengers on board: {___}")

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# List [...] is read from input, [...]. [...] Perform the following tasks: [...]
#
# **Code structure:**

# %%
tokens = input().split()
___ = []
for token in tokens:
    ___.append(int(token))
""" Your code goes here """

# %% [markdown]
# ---
#
# ## 8.3 Iterating over a list
#
# ### List iteration
#
# A programmer accesses each element of a list. Thus, learning how to iterate through a list using a loop is critical.
#
# Looping through a sequence such as a list is so common that Python supports a construct called a for loop, specifically for iteration purposes. The format of a for loop is shown below.
#
# > **Iterating through a list.**
# >

# %%
> for my_var in my_list:
>     # Loop body statements go here
>` ``

Each iteration of the loop creates a new variable by binding the next element of the list to the name my*var. The loop body statements execute during each iteration and can use the current value of my*var as necessary. 

Programs commonly iterate through lists to determine some quantity about the list's items. Ex: The following program determines the value of the maximum even number in a list:

> **Iterating through a list example: Finding the maximum even number.**
>

# %% [markdown]
# python
# > user_input = input("Enter numbers:")
# >
# > tokens = user_input.split()  # Split into separate strings
# >
# > # Convert strings to integers
# > nums = []
# > for token in tokens:
# >     nums.append(int(token))
# >
# > # Print each position and number
# > print()  # Print a single newline
# > for index in range(len(nums)):
# >     value = nums[index]
# >
# >     print(f"{index}: {value}")
# >
# > # Determine maximum even number
# > max_num = None
# > for num in nums:
# >     if (max_num == None) and (num % 2 == 0):
# >         # First even number found
# >         max_num = num
# >     elif (max_num != None) and (num > max_num ) and (num % 2 == 0):
# >         # Larger even number found
# >         max_num = num
# >
# > print(f"Max even #: {max_num}")
# >` `
# `>` `
# `> Enter numbers:3 5 23 -1 456 1 6 83
# > 0: 3
# > 1: 5
# > 2: 23
# > 3: -1
# > 4: 456
# > 5: 1
# > 6: 6
# > 7: 83
# > Max even #: 456
# > ....
# > Enter numbers:-5 -10 -44 -2 -27 -9 -27 -9
# > 0:-5
# > 1:-10
# > 2:-44
# > 3:-2
# > 4:-27
# > 5:-9
# > 6:-27
# > 7:-9
# > Max even #: -2
# >` ``
#
# If the user enters the numbers 7, -9, 55, 44, 20, -400, 0, 2, then the program will output `Max even #: 44`. The code uses three for loops. The first loop converts the strings obtained from the split() function into integers. The second loop prints each of the entered numbers. The first and second loops could easily be combined into a single loop, but the example uses two loops for clarity. The third loop evaluates each of the list elements to find the maximum even number.
#
# Before entering the first loop, the program creates the list nums as an empty list with the statement `nums = []`. The program then appends items to the list inside the first loop. Omitting the initial empty list creation would cause an error when the nums.append() function is called, because nums would not exist yet.
#
# The main idea of the code is to use a variable max*num to maintain the largest value seen so far as the program iterates through the list. During each iteration, if the list's current element value is even and larger than max*num so far, then the program assigns max_num with current value. Using a variable to track a value while iterating over a list is common behavior.
#
# ### PARTICIPATION ACTIVITY: Using a variable to keep track of a value while iterating over a list.
#
# nums = [1, 4, 15, 456]
#
# max*even = None
# for num in nums:
#     if num % 2 == 0: # The number is even?
#         if max*even == None or num > max*even:  # Greatest even number seen?
#             max*even = num
# End code block.
#
# Loop iterates over all elements of list nums.
# max_even set to None.
# First iteration of the for loop. num is set to 1. num is not even. First iteration of the for loops ends.
#
# Only larger even numbers update the value of max*even.
# Second iteration of the for loop. num is set to 4. max*even is set to 4.
#
# Odd numbers, or numbers smaller than max_even, are ignored.
# Next iteration of the for loop. num is set to 15. num is not even. This iteration of the for loop ends.
#
# When the loop ends, max*even is set to the largest even number 456.
# Last iteration of the for loop. num is set to 456. num is greater than max*even. max_even is not set to 456.
# For loop ends.
#
# A logic error in the above program would be to set max*even initially to 0 and then test `if max*even == 0`, because 0 is not in fact the largest value seen so far. Also, if the list nums only includes 0 and negative numbers, max_even would be  assigned with the largest negative number that comes after 0 in the list even though max_even should be 0. Ex:` nums = [-1, 0, -16, -2]` would result in max*even being assigned with -2.  Instead, the program sets max*even to None.
#
# ### PARTICIPATION ACTIVITY: List iteration.
#
# cnt_odd =
#
# **1.** Count how many odd numbers (cnt*odd) there are. for i in num:
#     if i % 2 == 1:
#         cnt*odd += 1
# Answer: 0
# *Hint: cnt*odd is incremented for each odd number in the list. The initial value should be 0.*
# *cnt*odd is incremented each time an odd number in the list is found.*
#
# cnt_neg = 0
# for i in num:
#     if i < 0:
#
# **2.** Count how many negative numbers (cnt*neg) there are.
# Answer: cnt*neg += 1 or cnt*neg = cnt*neg + 1
# *Hint: Increment cnt*neg if a negative number is found.*
# *cnt*neg is incremented each time a negative number in the list is found.*
#
# div_ten = 0
# for i in num:
#     if
#
# **3.** Determine the number of elements in the list that are divisible by 10. (Hint: The number x is divisible by 10 if x % 10 is 0.) :
#         div*ten += 1
# Answer: (i % 10 == 0) or i % 10 == 0
# *Hint: Use the modulus operator %.*
# *The div*ten variable is incremented each time that a number divisible by 10 is found.*
#
# > A for loop works on any iterable object. An iterable object is any object that can access each of its elements one at a time for most sequences such as lists, strings, and tuples are iterables. Thus, for loops are not specific to lists.
#
# ### IndexError and enumerate()
#
# A common error is to try to access a list with an index that is out of the list's index range, e.g., to try to access my*list[8] when my*list's valid indices are 0-7. Accessing an index that is out of range causes the program to automatically abort execution and generate an IndexError. Ex: For a list my*list containing 8 elements, the statement `my*list[10] = 42` produces output similar to:

# %%
Traceback (most recent call last):
 File "<stdin>", line 1, in <module>
IndexError: list assignment index out of range

# %% [markdown]
# Iterating through a list for various purposes is an extremely important programming skill to master.
#
# ### LAB ACTIVITY: Iterating through a list example: Finding the sum of a list's elements.
#
# Here is another example computing the sum of a list of integers. Note that the code is somewhat different than the code computing the max even value. For computing the sum, the program initializes a variable sum to 0, then simply adds the current iteration's list element value to that sum.
#
# Run the program below and observe the output. Next, modify the program to calculate the following:
#
#  - Compute the average, as well as the sum. Hint: Don't change the loop, just change the printed value.
#  - Print each number that is greater than 21.
#
# The built-in enumerate() function iterates over a list and provides an iteration counter. The program above uses the enumerate() function, which results in the variables pos and token being assigned the current loop iteration element's index and value, respectively. Thus, the first iteration of the loop assigns pos with 0 and token with the first user number; the second iteration assigns pos with 1 and token with the second user number; and so on.
#
# ### Built-in functions that iterate over lists
#
# Iterating through a list to find or calculate certain values like the minimum/maximum or sum is so common that Python provides built-in functions as shortcuts. Instead of writing a for loop and tracking a maximum value, or adding a sum, a programmer can use a statement such as `max(my_list)` or `sum(my_list)` to quickly obtain the desired value.
#
# > **Built-in functions supporting list objects.**
# > | Function | Description | Example code | Example output |
# > | --- | --- | --- | --- |
# > | all(list) | True if every element in list is True (!= 0), or if the list is empty. | print(all([1, 2, 3]))  print(all([0, 1, 2])) | `True False` |
# > | any(list) | True if any element in the list is True. | print(any([0, 2]))  print(any([0, 0])) | `True False` |
# > | max(list) | Get the maximum element in the list. | print(max([-3, 5, 25])) | `25` |
# > | min(list) | Get the minimum element in the list. | print(min([-3, 5, 25])) | `-3` |
# > | sum(list) | Get the sum of all elements in the list. | print(sum([-3, 5, 25])) | `27` |
#
# ### LAB ACTIVITY: Using built-in functions with lists.
#
# Complete the following program using functions from the table above to find some statistics about basketball player Lebron James. The code below provides lists of various statistical categories for the years 2003-2013. Compute and print the following statistics:
#
#  - Total career points
#  - Average points per game
#  - Years of the highest and lowest scoring season
#
# Use loops where appropriate.
#
# ### PARTICIPATION ACTIVITY: Lists and built-in functions.
#
# **1.** What value is returned by sum(my_list)?
# Answer: 30
# *Hint: sum() returns the sum of every element in the list.*
# *0+5+10+15 = 30*
#
# **2.** What value is returned by max(my_list)?
# Answer: 15
# *Hint: max() returns the largest element from the list.*
# *The largest element in the list is 15.*
#
# **3.** What value is returned by any(my_list)?
# Answer: True
# *Hint: any() returns a Boolean value True or False.*
# *The list contains non-zero elements, thus any() returns True.*
#
# **4.** What value is returned by all(my_list)?
# Answer: False
# *Hint: all() returns a Boolean value True or False.*
# *The list contains a 0 element, thus all() returns False because not all elements are non-zero.*
#
# **5.** What value is returned by min(my_list)?
# Answer:      `0`
# *Hint: min() returns the smallest element from the list.*
# *The smallest element in the list is 0.*
#
# ### CHALLENGE ACTIVITY: Sum extra credit.
#
# Organize the lines of code to create a for loop that sets sum_extra to the total extra credit received. Full credit is 100, so any grade over 100 has extra credit.
#
# Ex: If the input is:
#
# `101 83 107 90`
#
# then the output is:
#
# `Sum extra: 8`, because 1 + 0 + 7 + 0 is 8.
#
# Note: Not all lines of code on the left should be used in the final solution.
#
# **Solution:**

# %%
user_input = input()

# split() and map() are used to convert user_input
# to a list of integers
test_grades = list(map(int, user_input.split()))

sum_extra = 0
for grade in test_grades:
  if grade > 100:
    sum_extra = sum_extra + (grade - 100)

print(f"Sum extra: {sum_extra}")

# %% [markdown]
# **Distractor lines (wrong answers):**
#
# - `if grade < 100:`
# - `sum_extra = sum_extra - 100`
#
# ### CHALLENGE ACTIVITY: Iterating over a list. (3 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# List [...] contains integers read from input, representing data samples from an experiment. For each element in [...]: [...]
#
# **Explanation pattern:**
# A for loop may iterate through the indices of [...]. Alternatively, enumerate() may be used with a for loop to iterate through [...]. In each iteration: [...]
#
# **Code structure:**

# %%
# Read input and split input into tokens
tokens = input().split()

___ = []
for token in tokens:
    ___.append(int(token))

print(f"Raw samples: {___}")

___ = 0
""" Your code goes here """
print(f"Total ___ samples: {___}")

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# List [...] contains integers read from input, representing data samples from an experiment. [...] [...]
#
# **Explanation pattern:**
# [...] [...]
#
# **Code structure:**

# %%
# Read input and split input into tokens
tokens = input().split()

___ = []
for token in tokens:
    ___.append(int(token))

print(f"All data: {___}")
""" Your code goes here """

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# List [...] contains integers read from input, [...] [...] [...]
#
# **Explanation pattern:**
# [...] [...]
#
# **Code structure:**

# %%
# Read input and split input into tokens
tokens = input().split()

___ = []
for token in tokens:
    ___.append(int(token))

print(f"Sequence: {___}")
___
""" Your code goes here """

# %% [markdown]
# ---
#
# ## 8.4 List games
#
# The following activities can help programmers become comfortable with iterating through lists. Challenge yourself with these list games.
#
# ### PARTICIPATION ACTIVITY: Find the maximum value in the list.
#
# Question: The list contains seven elements, but the user is shown one value at a time. The user is tasked with finding the maximum value. If a new maximum value is seen, then indicate "Store value". The stored value will be updated to the new maximum value.
#
# Stored value = -1
#
# 51 Answer: Stored value = 51
#
# 95 Answer: Stored value = 95
#
# 13 Answer: Stored value = 95
#
# 36 Answer: Stored value = 95
#
# 10 Answer: Stored value = 95
#
# 68 Answer: Stored value = 95
#
# 64 Answer: Stored value = 95
#
# ### PARTICIPATION ACTIVITY: Negative value counting in list.
#
# Question: The list contains seven elements, but the user is shown one value at a time. The user is tasked with counting the negative values. If a negative value is seen, then indicate "Increment" to increment "Counter".
#
# Counter = 0
#
# -50 Answer: Increment, Counter = 1
#
# 34 Answer: Counter = 1
#
# 17 Answer: Counter = 1
#
# 41 Answer: Counter = 1
#
# 24 Answer: Counter = 1
#
# 7 Answer: Counter = 1
#
# 29 Answer: Counter = 1
#
# ### PARTICIPATION ACTIVITY: Manually sorting largest value.
#
# Question: The list contains seven elements, but the user is shown two neighboring values at a time. The user is tasked with moving the largest value to the right-most position of the list. If the larger of the two current values is on the left, then indicate "Swap values" to swap the values.
#
# Current values:
#
# 99 10 Answer: Swap values
#
# 99 59 Answer: Swap values
#
# 99 50 Answer: Swap values
#
# ---
#
# ## 8.5 List nesting
#
# Since a list can contain any type of object as an element, and a list is itself an object, a list can contain another list as an element.  Such embedding of a list inside another list is known as list nesting. Ex: The code `my_list = [[5, 13], [50, 75, 100]]` creates a list with two elements that are each another list.
#
# > **Multi-dimensional lists.**
# >

# %%
> my_list = [[10, 20], [30, 40]]
> print(f"First nested list: {my_list[0]}")
> print(f"Second nested list: {my_list[1]}")
> print(f"Element 0 of first nested list: {my_list[0][0]}")
>` `
`>` `
`> First nested list: [10, 20]
> Second nested list: [30, 40]
> Element 0 of first nested list: 10
>` ``

The program accesses elements of a nested list using syntax such as my_list[0][0].

### PARTICIPATION ACTIVITY: List nesting.

my_list = [   ["a", "b"], ["c", "d"], ["e", "f"]   ]
End code block.

The nested lists can be accessed using a single access operation.
my*list[0] is equal to ["a", "b"].
my*list[1] is equal to ["c", "d"].
my_list[2] is equal to ["e", "f"].

The elements of each nested list can be accessed using two indexing operations.
my*list[0][0] is equal to "a".
my*list[0][1] is equal to "b".
my*list[1][0] is equal to "c".
my*list[1][1] is equal to "d".
my*list[2][0] is equal to "e".
my*list[2][1] is equal to "f".

### PARTICIPATION ACTIVITY: List nesting.

**1.** Given the list nums = [[10, 20, 30], [98, 99]], what does nums[0][0] evaluate to?
Answer: 10
*Hint: nums[0] returns the list [10, 20, 30]. What's the first element of nums[0]?*
*nums[0] returns the list [10, 20, 30]. The first element of that list, nums[0][0], is 10.*

**2.** Given the list nums = [[10, 20, 30], [98, 99]], what does nums[1][1] evaluate to?
Answer: 99
*Hint: nums[1] returns the list [98, 99]. What's the second element of nums[1]?*
*nums[1] returns the list [98, 99]. The second element of that list, nums[1][1], is 99.*

**3.** Given the list nums = [[10, 20, 30], [98, 99]], what does nums[0] evaluate to?
Answer: [10, 20, 30]
*Hint: What's the first element of nums? Hint: It's a list.*
*nums[0] returns the list [10, 20, 30].*

**4.** Create a nested list called nums whose only element is the list [21, 22, 23].
Answer: nums = [[21, 22, 23]]
*Hint: nums = [[?, ?, ?]]*
*The outer brackets create a list containing lists, and the inner brackets contain the number elements.*

A list is a single-dimensional sequence of items, like a series of times, data samples, daily temperatures, etc. List nesting allows for a programmer to also create a multi-dimensional data structure, the simplest being a two-dimensional table, like a spreadsheet or tic-tac-toe board. The following code defines a two-dimensional table using nested lists:

> **Representing a tic-tac-toe board using nested lists.**
>

# %% [markdown]
# python
# > tic_tac_toe = [
# >     ["X", "O", "X"],
# >     [" ", "X", " "],
# >     ["O", "O", "X"]
# > ]
# >
# > print(tic_tac_toe[0][0], tic_tac_toe[0][1], tic_tac_toe[0][2])
# > print(tic_tac_toe[1][0], tic_tac_toe[1][1], tic_tac_toe[1][2])
# > print(tic_tac_toe[2][0], tic_tac_toe[2][1], tic_tac_toe[2][2])
# >` `
# `>` `
# `> X O X
# >   X
# > O O X
# >` ``
#
# The example above creates a variable tic*tac*toe that represents a two-dimensional table with three rows and three columns, for 3*3=9 total table entries. Each row in the table is a nested list. Table entries can be accessed by specifying the desired row and column: tic*tac*toe [1][1] accesses the middle square in row 1, column 1 (starting from 0), which has a value of "X". The following animation illustrates:
#
# ### PARTICIPATION ACTIVITY: Two-dimensional list.
#
# my_list = [
#     [10, 0, 55],
#     [0, 4, 16]
# ]
#
# \# Write to some elements
#
# my*list[0][0] = 33
# my*list[1][1] = 77
# my_list[1][2] = 99
#
# List my*list contains two lists as elements: my*list[0] is [10, 0, 55] and my_list[1] is [0, 4, 16].
#
# my_list conceptually as a table with 2 rows and 3 columns.
#
# Column 0
# Column 1
# Column 2
#
# Row 0
# 10, accessed by [0][0]
# 0,  accessed by [0][1]
# 55,  accessed by [0][2]
#
# Row 1
# 0, accessed by [1][0]
# 4, accessed by [1][1]
# 16, accessed by [1][2]
#
# my*list conceptually as a table after the following three lines of code are executed:
# my*list[0][0] = 33
# my*list[1][1] = 77
# my*list[1][2] = 99
#
# Column 0
# Column 1
# Column 2
#
# Row 0
# previously 10, updated to 33
# 0
# 55
#
# Row 1
# 0
# previously 4, updated to 77
# previously 16, updated to 99
#
# ### LAB ACTIVITY: Two-dimensional list example: Driving distance between cities.
#
# The following example illustrates the use of a two-dimensional list in a distance between cities.
#
# Run the following program, entering the text "1 2" as input to find the distance between LA and Chicago. Try other pairs. Next, try modifying the program by adding a new city, Anchorage, that is 3400, 3571, and 4551 miles from Los Angeles, Chicago, and Boston, respectively.
#
# Note that the styling of the nested list in this example makes use of indentation to clearly indicate the elements of each list. The spacing does not affect how the interpreter evaluates the list contents.
#
# The level of nested lists is arbitrary. A programmer might create a three-dimensional list structure as follows:
#
# > **The level of nested lists is arbitrary.**
# >

# %%
> nested_table = [
>     [
>         [10, 0, 55],
>         [0, 4, 16]
>     ],
>     [
>         [0, 0, 1],
>         [1, 20, 2]
>     ]
> ]
>` ``

A number from the above three-dimensional list could be accessed using three indexing operations, as in `nested_table[1][1][1]`.

### PARTICIPATION ACTIVITY: Multi-dimensional lists.

**1.** Write an indexing expression that gets the element from scores whose value is 100.
Answer: scores[0][1]
*Hint: Use two indexing operations to get the value: scores[?][?].*
*The first indexing operation scores[0] gets the list [75, 100, 82, 76]. The second operation scores[0][1] gets 100.*

**2.** How many elements does scores contain? (The result of len(scores))
Answer: 3
*Hint: scores has three elements that are lists.*
*scores has three elements that are lists. The elements of those lists don't count as elements of scores.*

As always with lists, a typical task is to iterate through the list elements. A programmer can access all of the elements of nested lists by using nested for loops. The first for loop iterates through the elements of the outer list (rows of a table), while the nested loop iterates through the inner list elements (columns of a table). The code below defines a 3x3 table and iterates through each of the table entries.

### PARTICIPATION ACTIVITY: Iterating over multi-dimensional lists.

currency = [

        [1.00, 5.00, 10.0], # US Dollars
        [0.75, 3.77, 7.53], # Euros
        [0.65, 3.25, 6.50]  # British pounds
]

for row in currency:
    for cell in row:
        print(cell, end=" ")
    print()

In the program's nested for loop, the outer loop iterates three times, once for each row within list currency. For each iteration of the outer loop, the inner loop iterates three times, once for each cell within the row. The inner loop's print statement outputs cell's value followed by a space. After the inner loop terminates, the outer loop prints a newline and proceeds to the next iteration. After three iterations of the outer loop, the outer loop terminates.

Outer loop iteration
Inner loop iteration
Output console

1
1
1.00 

1
2
1.00 5.00 

1
3
1.00 5.00 10.00 

2
1
1.00 5.00 10.00 
0.75 

2
2
1.00 5.00 10.00 
0.75 3.77 

2
3
1.00 5.00 10.00 
0.75 3.77 7.53 

3
1
1.00 5.00 10.00 
0.75 3.77 7.53 
0.65 

3
2
1.00 5.00 10.00 
0.75 3.77 7.53 
0.65 3.25 

3
3
1.00 5.00 10.00 
0.75 3.77 7.53 
0.65 3.25 6.50

The outer loop assigns the variable row with one of the list elements. The inner loop then iterates over the elements in that list. Ex: On the first iteration of the outer loop, row is [1, 5, 10]. The inner loop then assigns cell 1 on the first iteration, 5 on the second iteration, and 10 on the last iteration.

Combining nested for loops with the enumerate() function gives easy access to the current row and column below.

> **Iterating through multi-dimensional lists using enumerate().**
>

# %% [markdown]
# python
# > currency = [
# >    [1, 5, 10 ],  # US Dollars
# >    [0.75, 3.77, 7.53],  #Euros
# >    [0.65, 3.25, 6.50]  # British pounds
# > ]
# > for row_index, row in enumerate(currency):
# >    for column_index, item in enumerate(row):
# >        print(f"currency[{row_index}][{column_index}] is {item:.2f}")
# >` `
# `>` `
# `> currency[0][0] is 1.00
# > currency[0][1] is 5.00
# > currency[0][2] is 10.00
# > currency[1][0] is 0.75
# > currency[1][1] is 3.77
# > currency[1][2] is 7.53
# > currency[2][0] is 0.65
# > currency[2][1] is 3.25
# > currency[2][2] is 6.50
# >` ``
#
# ### PARTICIPATION ACTIVITY: Find the error.
#
# **1.**

# %% [markdown]
# **2.**

# %%
X wins!

# %% [markdown]
# ### CHALLENGE ACTIVITY: List nesting. (4 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# [...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# Two-dimensional list [...] represents a 3x3 tic-tac-toe game board read from input. List [...] contains three lists, each representing a row. Each list has three elements representing the three columns on the board. Each element in the tic-tac-toe game board is "x", "o", or "-". [...] Note: The logical test (a == "[...]" and b == "[...]" and c == "[...]") returns True if a, b, and c are equal to "[...]". The logical test returns False otherwise.
#
# **Explanation pattern:**
# [...] is a two-dimensional list. [...][i] returns the one-dimensional list corresponding to the row at index i. Thus, [...][i][j] corresponds to the element at row index i and column index j of [...]. Both row indices and column indices of [...] have values that range from 0 to 2. If the elements at [...][[...]][[...]], [...][[...]][[...]], and [...][[...]][[...]] are all equal to "[...]", then [...]
#
# **Code structure:**

# %%
___ = [
  input().split(),
  input().split(),
  input().split()
]
""" Your code goes here """

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# Integer [...] is read from input, representing the number of rows of data remaining in the input. Two-dimensional list [...] consists of data read from the remaining input[...]
#
# **Explanation pattern:**
# A nested for loop is used to access each element of [...]. [...]
#
# **Code structure:**

# %%
___ = int(input())
___ = []
for row_index in range(___):
    ___
""" Your code goes here """

# %% [markdown]
# **Level 4:**
#
# **Task pattern:**
# Integer grid_size is read from input, representing the number of rows and columns of a two-dimensional list. Two-dimensional list [...] is created with [...]s, [...], as the initial values. For each element at row index [...] and column index [...] of [...], [...].
#
# **Explanation pattern:**
# A nested for loop is used to iterate through the row index and column index of each element in [...]. For each row index [...] and column index [...] of [...], [...]. Ex: For input [example_input], [...] has [...] rows and [...] columns. For row index [...] and column index [...] ranging from 0 to [...], both inclusive, [...][[...]][[...]] is assigned with [...]. Thus: [...]
# The remaining elements are [...] accordingly.
#
# **Code structure:**

# %%
grid_size = int(input())

___ = []
for ___ in range(grid_size):
    row = []
    for ___ in range(grid_size):
        row.append(___)
    ___.append(row)
""" Your code goes here """
for row in ___:
    for cell in row:
        print(cell, end="___")
    print()

# %% [markdown]
# ---
#
# ## 8.6 List slicing
#
# A programmer can use slice notation to read multiple elements from a list, creating a new list that contains only the desired elements. The programmer indicates the start and end positions of a range of elements to retrieve, as in `my_list[0:2]`. The 0 is the position of the first element to read, and the 2 indicates the last element. Every element between 0 and 2 from my_list is in the new list. The end position, 2, is *not* included in the resulting list.
#
# > **List slice notation.**
# >

# %%
> boston_bruins = ["Tyler", "Zdeno", "Patrice"]
> print(f"Elements 0 and 1: {boston_bruins[0:2]}")
> print(f"Elements 1 and 2: {boston_bruins[1:3]}")
>` `
`>` `
`> Elements 0 and 1: ['Tyler', 'Zdeno']
> Elements 1 and 2: ['Zdeno', 'Patrice']
>` ``

The slice `boston_bruins[0:2]` produces a new list containing the elements in positions 0 and 1: ['Tyler', 'Zdeno']. The end position is *not* included in the produced list &ndash; to include the final element of a list in a slice, specify an end position past the end of the list. Ex: `boston_bruins[1:3]` produces the list ['Zdeno', 'Patrice'].

### PARTICIPATION ACTIVITY: List slicing.

my_list = ["practicing", "with", "list", "slicing"]

print(my*list[0:3])
print(my*list[1:2])

Index
Element's value

0
"practicing"

1
"with"

2
"list"

3
'slicing'

print(my_list[0:3]) produces a new list containing the elements from indices 0 to 2, then outputs the new list to the console. The end position, position 3 with value "slicing", is not included in the produced list. Thus, the output to the console is ["practicing", "with", "list"] followed by a newline. 

print(my_list[1:2]) produces a new list containing the element at index 1, then outputs the new list to the console. The end position, position 2 with value "list", is not included in the produced list.Thus, the output to the console is ["with"] followed by a newline.

Negative indices can also be used to count backward from the end of the list.

> **List slicing: Using negative indices.**
>

# %% [markdown]
# python
# > election_years = [1992, 1996, 2000, 2004, 2008]
# > print(election_years[0:-1])  # Every year except the last
# > print(election_years[0:-3])  # Every year except the last three
# > print(election_years[-3:-1])  # The third and second to last years
# >` `
# `>` `
# `> [1992, 1996, 2000, 2004]
# > [1992, 1996]
# > [2000, 2004]
# >` ``
#
# A position of -1 refers to the last element of the list, thus election*years[0:-1] creates a slice containing all but the last election year. Such usage of negative indices is especially useful when the length of a list is not known and is simpler than the equivalent expression election*years[0:len(election_years)-1].
#
# ### PARTICIPATION ACTIVITY: List slicing.
#
# **1.** What is the result of nums[1:5]?
# Answer: [1, 2, 3, 5]
# *Hint: The result list contains four elements, starting at position 1. [?, ? ....]*
# *The slice obtains the elements in positions 1-4.*
#
# **2.** What is the result of nums[5:10]?
# Answer: [8, 13]
# *Hint: An end position greater than the length of the list is assumed to refer to the end of the list.*
# *The list contains seven elements. Specifying an end position 8 or higher simply obtains all elements of the list beginning at the start position.*
#
# **3.** What is the result of nums[3:-1]?
# Answer: [3, 5, 8]
# *Hint: Position -1 refers to the last element in the list.*
# *Elements from position 3 until the second to last element are included in the slice.*
#
# An optional component of slice notation is the stride, which indicates how many elements are skipped between extracted items in the source list. Ex: The expression my*list[0:5:2] has a stride of 2, thus skipping every other element, and resulting in a slice that contains the elements in positions 0, 2, and 4. The default stride value is 1 (the expressions my*list[0:5:1] and my_list[0:5] being equivalent).
#
# If the reader has studied string slicing, then list slicing should be familiar. In fact, slicing has the same semantics for most sequence-type objects.
#
# ### PARTICIPATION ACTIVITY: List slicing.
#
# **1.** The result of evaluating nums[0:5:2] is [25, 75].
#
# **2.** The result of evaluating nums[0:-1:3] is [0, 75].
#
# A table of common list slicing operations is given below. Note that omission of the start or end positions, such as my*list[:2] or my*list[4:], has the same meaning as in string slicing. my*list[:2] includes every element up to position 2. my*list[4:] includes every element following position 4 (including the element at position 4).
#
# > **Common list slicing operations.**
# > | Operation | Description | Example code | Example output |
# > | --- | --- | --- | --- |
# > | my*list[start:end] | Get a list from start to end (minus 1). | my*list = [5, 10, 20]  print(my*list[0:2]) | `[5, 10]` |
# > | my*list[start:end:stride] | Get a list of every stride element from start to end (minus 1). | my*list = [5, 10, 20, 40, 80]  print(my*list[0:5:3]) | `[5, 40]` |
# > | my*list[start:] | Get a list from start to end of the list. | my*list = [5, 10, 20, 40, 80]  print(my*list[2:]) | `[20, 40, 80]` |
# > | my*list[:end] | Get a list from beginning of the list to the end (minus 1). | my*list = [5, 10, 20, 40, 80]  print(my*list[:4]) | `[5, 10, 20, 40]` |
# > | my*list[:] | Get a copy of the list. | my*list = [5, 10, 20, 40, 80]  print(my_list[:]) | `[5, 10, 20, 40, 80]` |
#
# The interpreter handles incorrect or invalid start and end positions in slice notation gracefully. An end position that exceeds the length of the list is treated as the end of the list. If the end position is less than the start position, an empty list is produced.
#
# ### PARTICIPATION ACTIVITY: Match the expressions to the list.
#
# ### CHALLENGE ACTIVITY: Enter the output of the sliced list.
#
# **Level 1:**
#
# What is the output?

# %%
my_list = [13, 14, 15, 16, 17, 18, 19]
new_list = my_list[0:2]
print(new_list)

# %% [markdown]
# *In `new_list = my_list[0:{{last_position}}]`, 0 is the first position of my*list in new*list. {{last*position}} is the first position of my*list that is not in new_list.*
#
# **Level 2:**
#
# What is the output?

# %%
my_list = [13, 14, 15, 16, 17, 18, 19]
new_list = my_list[0:5:{{stride.number}}]
print(new_list)

# %% [markdown]
# *In `new_list = my_list[0:{{last_position}}:{{stride.number}}]`, 0 is the first position of my*list in new*list. {{last*position}} is the first position of my*list that is not in new*list. {{stride.number}} is the stride and specifies that every {{stride.ordinal}} element of my*list is extracted.*
#
# **Level 3:**
#
# What is the output?

# %%
my_list = [13, 14, 15, 16, 17, 18, 19]
new_list = my_list[1:4]
print(new_list)

# %% [markdown]
# *In `new_list = my_list[{{first_position}}:{{last_position}}]`, {{first*position}} is the first position of my*list in new*list. {{last*position}} is the first position of my*list that is not in new*list.*
#
# **Level 4:**
#
# What is the output?

# %%
my_list = [13, 14, 15, 16, 17]
new_list = my_list[0:{{last_element.number}}]
print(new_list)

# %% [markdown]
# *In `new_list = my_list[0:{{last_element.number}}]`, 0 is the first position of my*list in new*list. {{last*element.number}} is the {{last*element.ordinal}}last position of my*list, which is the first position that is not in new*list.*
#
# **Level 5:**
#
# What is the output?

# %%
my_list = [13, 14, 15, 16, 17]
new_list = my_list[{{first_element.number}}:{{last_element.number}}]
print(new_list)

# %% [markdown]
# *In `new_list = my_list[{{first_element.number}}:{{last_element.number}}]`, {{first*element.number}} is the {{first*element.ordinal}}-to-last position of my*list, which is the first position in new*list. {{last*element.number}} is the {{last*element.ordinal}}last position of my*list, which is the first position that is not in new*list.*
#
# ### CHALLENGE ACTIVITY: List slicing. (3 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# List [...] is read from input. Assign [...] with a slice of [...].
#
# **Explanation pattern:**
# [...][start*index:end*index] creates a slice of [...] that starts at index start*index (inclusive) and ends at end*index (exclusive). Using [...] for start*index and [...] for end*index specifies a range [...].
#
# **Code structure:**

# %%
___ = input().split()
""" Your code goes here """
print(f"___: {___}")
print(f"___: {___}")

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# List [...] is read from input[...]. Assign [...] with len([...]) // [...].
# Assign [...] with a slice of [...] from the beginning up to and excluding index [...].[...]
# Assign [...] with a slice of [...] from index [...][...] up to and including the end.
#
# **Explanation pattern:**
# [...][:end*index] creates a slice of [...] that starts at index 0 (inclusive) and ends at end*index (exclusive). Using [...] for end*index selects every element in the first [...] of [...].
# [...][start*index:] creates a slice of [...] that starts at index start*index (inclusive) and ends at the end of [...] (inclusive). Using [...][...] for start*index selects every element in the last [...] of [...].
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# List [...] is read from input. Perform the following tasks: Assign [...] with a copy of [...] using [:].
# Assign [...] with [...]
#
# **Explanation pattern:**
# [...][:] creates a copy of [...]. [...][start*index:end*index:stride*value] creates a slice of [...] from start*index (inclusive) to end*index (exclusive) with a stride of stride*value. Using [...] for start*index and len([...]) for end*index specifies the range from index [...] up to and including the end. Using [...] for stride_value selects every [...] element. The first element selected is at index [...]. The subsequent elements selected are at [...]
#
# **Code structure:**

# %%
""" Your code goes here """
___.clear()
print(f"___: {___}")
print(f"___: {___}")

# %% [markdown]
# ---
#
# ## 8.7 Loops modifying lists
#
# Sometimes a program iterates over a list while modifying the elements, such as changing some elements' values or moving elements' positions.
#
# ### Changing elements' values
#
# The below example of changing elements' values combines the len() and range() functions to iterate over a list and increment each element of the list by 5.
#
# > **Modifying a list during an iteration example.**
# >

# %%
> my_list = [3.2, 5.0, 16.5, 12.25]
> 
> for i in range(len(my_list)):
>     my_list[ i ] += 5
>` ``

The figure below shows two programs that each attempt to convert any negative numbers in a list to 0. The program on the right is incorrect, demonstrating a common logic error.

> **Modifying a list during iteration example: Converting negative values to 0.**
> | user*input = input("Enter numbers: ")  tokens = user*input.split()  # Convert strings to integers nums = [] for token in tokens:     nums.append(int(token))  # Print each position and number print() for pos, val in enumerate(nums):            print(f"{pos}: {val}")  # Change negative values to 0 for pos in range(len(nums)):     if nums[pos] < 0:         nums[pos] = 0  # Print new numbers print("New numbers: ") for num in nums:     print(num, end=" ") |
> | `Enter numbers:5 67 -5 -4 5 6 6 4 0: 5 1: 67 2: -5 3: -4 4: 5 5: 6 6: 6 7: 4 New numbers:  5 67 0 0 5 6 6 4` |
> | user*input = input("Enter numbers:")  tokens = user*input.split()  # Convert strings to integers nums = [] for token in tokens:     nums.append(int(token))  # Print each position and number print() for pos, val in enumerate(nums):            print(f"{pos}: {val}")  # Change negative values to 0 for num in nums:     if num < 0:         num = 0  # Logic error: temp variable num set to 0  # Print new numbers print("New numbers: ") for num in nums:     print(num, end=" ") |
> | `Enter numbers:5 67 -5 -4 5 6 6 4 0: 5 1: 67 2: -5 3: -4 4: 5 5: 6 6: 6 7: 4 New numbers:  5 67 -5 -4 5 6 6 4` |

The program on the right illustrates a common logic error. A common error when modifying a list during iteration is to update the loop variable instead of the list object. The statement `num = 0` simply binds the name num to the integer literal value 0. The reference in the list is never changed. 

 In contrast, the program on the left correctly uses an index operation `nums[pos] = 0` to modify to 0 the reference held by the list in position pos. The below activities demonstrate further. Only the second program changes the list's values.

### CHALLENGE ACTIVITY: Iterating through a list using range().

**Level 1:**

What is the output?

# %% [markdown]
# python
# user_values = [1, 4, 7]
#
# for i in range(len(user_values)):
#    print(user_values[i])

# %%
*`user_values = [{{firstElement}}, {{secondElement}}, {{thirdElement}}]` assigns user_values with  a list. Then, each element is initialized in order with {{firstElement}}, {{secondElement}}, and {{thirdElement}}. The program outputs the value of each element in order.*

**Level 2:**

What is the output?

# %% [markdown]
# python
# user_values = [1, 4, 7]
# sum_value = 0
#
# for i in range(len(user_values)):
#   sum_value += user_values[i]
#
# print(sum_value)

# %%
*user*values is assigned a list with three elements. Then the value of each element is added to sum*value and the final value of sum_value is printed.*

**Level 3:**

What is the output?

# %% [markdown]
# python
# user_values = [-1, 3, 5, -7]
#
# for i in range(len(user_values)):
#   if user_values[i] < 0:
#     print(user_values[i])

# %%
*`user_values = [{{firstElement}}, {{secondElement}}, {{thirdElement}}, {{fourthElement}}]` assigns user_values with  a list. The values in the list are checked in order against 0. If the checked value is less than 0, then the checked value is printed.*

**Level 4:**

What is the output?

# %% [markdown]
# python
# user_values = [-1, 3, -5, 7]
#
# for i in range(len(user_values)):
#   if user_values[i] < 0:
#     user_values[i] = -1 * user_values[i]
#   print(user_values[i])

# %%
*user_values is assigned a list with four elements. The values in the list are checked in order against 0. If the checked value is less than 0, that value is multiplied by -1. All values are printed.*

**Level 5:**

What is the output?

# %% [markdown]
# python
# user_values = [1, 5, 7, 3]
#
# max_value = user_values[0]
# for i in range(len(user_values)):
#   if user_values[i] >= max_value:
#     max_value = user_values[i]
#     print(max_value)

# %%
*user*values is assigned a list with four elements. max*value is initialized to the value of the first element in the list, {{firstElement}}. The values of the list are checked in order against the value of max*value. If the checked value is at least as large as max*value, then max_value is assigned that checked value, and printed.*

### PARTICIPATION ACTIVITY: List modification.

What's the final value of nums[1]?
Answer: 10.0 or 10
*Hint: In the second iteration of the loop, pos = 1 and value = 20. Thus, tmp = value/2 = 10.0.*
*tmp is assigned the value 10.0. Because 10.0 is an even number, tmp%2 is 0 and the branch executes. `nums[pos] = tmp` assigns nums[1] with 10.0.*

### Changing list size

A common error is to add or remove a list element while iterating over that list. Such list modification can lead to unexpected behavior if the programmer is not careful. Ex: Consider the following program that reads in two sets of numbers and attempts to find numbers in the first set that are not in the second set.

> **Modifying lists while iterating: Incorrect program.**
>

# %% [markdown]
# python
# > nums1 = []
# > nums2 = []
# >
# > user_input = input("Enter first set of numbers: ")
# > tokens = user_input.split()  # Split into separate strings
# >
# > # Convert strings to integers
# > print()
# > for pos, val in enumerate(tokens):
# >     nums1.append(int(val))
# >     print(f"{pos}: {val}")
# >
# > user_input = input("Enter second set of numbers: ")
# > tokens = user_input.split()
# >
# > # Convert strings to integers
# > print()
# > for pos, val in enumerate(tokens):
# >     nums2.append(int(val))
# >     print(f"{pos}: {val}")
# >
# > # Remove elements from nums1 if also in nums2
# > print()
# > for val in nums1:
# >     if val in nums2:
# >         print(f"Deleting {val}")
# >         nums1.remove(val)
# >
# > # Print new numbers
# > print("\nNumbers only in first set:", end=" ")
# > for num in nums1:
# >     print(num, end=' ')
# >` `
# `>` `
# `> Enter first set of numbers: 5 10 15 20
# > 0: 5
# > 1: 10
# > 2: 15
# > 3: 20
# > Enter second set of numbers: 15 20 25 30
# > 0: 15
# > 1: 20
# > 2: 25
# > 3: 30
# >
# > Deleting 15
# >
# > Numbers only in first set: 5 10 20
# >` ``
#
# The above example iterates over the list nums1, deleting an element from the list if the element is also found in the list nums2. The programmer expected a certain result, namely that after removing an element from the list, the next iteration of the loop would reference the next element as normal. However, removing the element shifts the position of each following element in the list to the left by one. In the example above, removing 15 from nums1 shifts the value 20 left into position 2. The loop, having just iterated over position 2 and removing 15, moves to the next position and finds the end of the list, thus never evaluating the final value 20.
#
# The problem illustrated by the example above has a simple fix: Iterate over a copy of the list instead of the actual list being modified. Copying the list allows a programmer to modify, swap, add, or delete elements without affecting the loop iterations. The easiest way to copy the iterating list is to use slice notation inside of the loop expression, as in the example below.
#
# > **Copy a list using [:].**
# >

# %%
> for item in my_list[:]:
>     # Loop statements.
>` ``

### PARTICIPATION ACTIVITY: List modification.

nums1 = [5, 10, 15]
nums2 = [10, 15]

for val in nums1:
    if val in nums2:
        nums1.remove(val)

The program's for loop iterates through each val in nums1: [5, 10, 15]. Within the for loop, the if statement checks to see if the current val is in nums2: [10, 15]. If the current val is in nums2, the value is removed from nums1.

Index 0 of nums1 contains 5, which is not in nums2.

Index 1 of nums1 contains 10, which is in nums2. Thus, 10 is removed from nums1 and nums1 is now [5, 15].

Since nums1 now has only two elements, there is no index 2, thus the for loop terminates.

The program's for loop statement, for val in nums1, is changed to for val in nums1[:]. Thus, the program's for loop now iterates through each val in a copy of nums1: [5, 10, 15].

Index 0 of the copy of nums1 contains 5, which is not in nums2.

Index 1 of the copy of nums1 contains 10, which is in nums2. Thus, 10 is removed from nums1 and nums1 is now [5, 15].

Index 2 of the copy of nums1 contains 15, which is in nums2. Thus, 15 is removed from nums1 and nums1 is now [5].

### LAB ACTIVITY: Modify the above program to work correctly.

Modify the program (copied from above) using slice notation to iterate over a copy of the list.

### PARTICIPATION ACTIVITY: Modifying a list while iterating.

**1.** Iterating over a list and deleting elements from the original list might cause a logic program error.

**2.** A programmer can iterate over a copy of a list to safely make changes to the original list.

### CHALLENGE ACTIVITY: Loops modifying lists. (3 Levels)

**Level 1:**

**Task pattern:**
List [...] contains integers read from input. [...]

**Explanation pattern:**
A for loop iterates through each index of [...] using the values returned by range(len([...])). [...] The updated [...] has elements [...].

**Code structure:**

# %% [markdown]
# python
# ___ = []
#
# tokens = input().split()
# for token in tokens:
#     ___.append(int(token))
#
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()
# """ Your code goes here """
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()

# %%
**Level 2:**

**Task pattern:**
List [...] contains integers read from input. [...]

**Explanation pattern:**
A for loop iterates through a copy of [...] using [:]. [...]

**Code structure:**

# %% [markdown]
# python
# ___ = []
#
# tokens = input().split()
# for token in tokens:
#     ___.append(int(token))
#
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()
# """ Your code goes here """
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()

# %%
**Level 3:**

**Task pattern:**
List [...] contains words read from the first line of input. List [...] contains words read from the second line of input. For each element in [...] that is [...] in [...]: Output the element, followed by "[...]".
Remove the element from [...].

**Explanation pattern:**
A for loop iterates through a copy of [...] using [:]. For each element in the copy of [...], if the element is [...] in [...], then: The element is output, followed by "[...]".
A call to [...]'s remove() removes the element from [...]. [...]

**Code structure:**

# %% [markdown]
# python
# ___ = input().split()
# ___ = input().split()
#
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()
#
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()
# """ Your code goes here """
# print("___", end=" ")
# for ___ in ___:
#     print(___, end=" ")
# print()

# %%
---

## 8.8 List comprehensions

A programmer modifies every element of a list in the same way, such as adding 10 to every element. The Python language provides a convenient construct, known as list comprehension, that iterates over a list, modifies each element, and returns a new list of the modified elements.

A list comprehension construct has the following form:

> **List comprehension.**

A list comprehension has three components: 

 - An *expression component* to evaluate for each element in the iterable object.
 - A *loop variable component* to bind to the current iteration element.
 - An *iterable object component* to iterate over (list, string, tuple, enumerate, etc).

A list comprehension is always surrounded by brackets, which is a helpful reminder that the comprehension builds and returns a new list object. The loop variable and iterable object components make up a normal for loop expression. The for loop iterates through the iterable object as normal, and the expression operates on the loop variable in each iteration. The result is a new list containing the values modified by the expression. The program below demonstrates a simple list comprehension that increments each value in a list by 5.

> **List comprehension example: A first look.**
>

# %% [markdown]
# python
# > my_list = [10, 20, 30]
# > list_plus_5 = [(i + 5) for i in my_list]
# >
# > print(f"New list contains: {list_plus_5}")
# >` `
# `>` `
# `> New list contains: [15, 25, 35]
# >` ``
#
# The following animation illustrates:

# %% [markdown]
# ### PARTICIPATION ACTIVITY: List comprehension.
#
# my*list = [50, 23, -4]
# my*list*minus10 = [(i - 10) for i in my*list]
#
# The for loop iterates through each value of my*list. Within the for loop, 10 is subtracted from the value, and the result is appended to the new list, my*list*minus10.
#
# The first value of my*list is 50, and 50 minus 10 is 40. The second value of my*list is 23, and 23 minus 10 is 13. The third and final value of my*list is negative 4, and negative 4 minus 10 is negative 14. The for loop terminates and my*list_minus10 contains [40, 13, -14].
#
# Programmers commonly prefer using a list comprehension rather than a for loop in many situations. Such preference is due to less code and more efficient execution by the interpreter. The table below shows various for loops and equivalent list comprehensions.
#
# > **List comprehensions can replace some for loops.**
# > | Num | Description | For loop | Equivalent list comprehension | Output of both programs |
# > | --- | --- | --- | --- | --- |
# > | 1 | Add 10 to every element. | my*list = [5, 20, 50] for i in range(len(my*list)):     my*list[ i ] += 10 print(my*list) | my*list = [5, 20, 50] my*list = [(i+10) for i in my*list] print(my*list) | [15, 30, 60] |
# > | 2 | Convert every element to a string. | my*list = [5, 20, 50] for i in range(len(my*list)):     my*list[ i ] = str(my*list[ i ]) print(my*list) | my*list = [5, 20, 50] my*list = [str(i) for i in my*list] print(my*list) | ['5', '20', '50'] |
# > | 3 | Convert user input to a list of integers. | inp = input("Enter numbers:") my*list = [] for i in inp.split():     my*list.append(int(i)) print(my*list) | inp = input("Enter numbers:") my*list = [int(i) for i in inp.split()] print(my*list) | Enter numbers: 7 9 3 [7, 9, 3] |
# > | 4 | Find the sum of each row in a two-dimensional list. | my*list = [[5, 10, 15], [2, 3, 16], [100]] sum*list = [] for row in my*list:     sum*list.append(sum(row)) print(sum*list) | my*list = [[5, 10, 15], [2, 3, 16], [100]] sum*list = [sum(row) for row in my*list] print(sum*list) | [30, 21, 100] |
# > | 5 | Find the sum of the row with the smallest sum in a two-dimensional table. | my*list = [[5, 10, 15], [2, 3, 16], [100]] sum*list = [] for row in my*list:     sum*list.append(sum(row)) min*row = min(sum*list) print(min*row) | my*list = [[5, 10, 15], [2, 3, 16], [100]] min*row = min([sum(row) for row in my*list]) print(min*row) | 21 |
