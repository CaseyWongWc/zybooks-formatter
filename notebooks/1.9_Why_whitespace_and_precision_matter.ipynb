# %% [markdown]
# ## 1.9 Why whitespace and precision matter

# %% [markdown]
# ### Whitespace and precise formatting
#
# For program output,  whitespace is any blank space or newline. Most coding activities  require a student program's output to match exactly the expected output, including whitespace. Students learning programming often complain:
#
# "My program is correct, but the system is complaining about output whitespace."
#
# However, correctness often includes formatting.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Precisely formatting a meeting invite.
#
# Static figure: Two examples of meeting invites. The first example was programmed with whitespace in mind, the second example was programmed without being careful with whitespace. Example 1:
# Kia Smith is inviting you
# to a video meeting.
#
# Join meeting:
#   http://www.zoomskype.us/5592
#
# Phone:
#   1-669-555-2634 (San Jose)
#   1-929-555-4000 (New York)
#
# Meeting ID: 5592

# %% [markdown]
# -------------------------

# %% [markdown]
# Reminder: 10 min before
# Example 2:
# Kia Smith is inviting you to a video
# meeting. Join meeting:
#
# http://www.zoomskype.us/5592 Phone:
# 1-669-555-2634 (San Jose)
# 1-929-555-4000 (New York)
#
# Meeting ID: 5592
# ------------------------- Reminder: 10 min
# before
# Step 1: This program for online meetings not only computes a schedule and creates a unique meeting ID, but the program also outputs text formatted neatly for a calendar event. The following text appears: Kia Smith is inviting you
# to a video meeting.
#
# Join meeting:
#   http://www.zoomskype.us/5592
#
# Phone:
#   1-669-555-2634 (San Jose)
#   1-929-555-4000 (New York)
#
# Meeting ID: 5592

# %% [markdown]
# -------------------------

# %% [markdown]
# Step 2: A calendar program may append more text after the meeting invitation text. The following text appears on the next line: Reminder: 10 min before.
# Step 3: The programmer of the invitation on the right wasn't careful with whitespace. "Join meeting" is buried, the link is hard to see, and the "Phone" text is dangling at a line's end. The following text appears: Kia Smith is inviting you to a video
# meeting. Join meeting:
#
# http://www.zoomskype.us/5592 Phone:
# 1-669-555-2634 (San Jose)
# 1-929-555-4000 (New York)
#
# Meeting ID: 5592

# %% [markdown]
# -------------------------

# %% [markdown]
# Step 4: The programmer also didn't end with a newline, causing subsequent text to appear at the end of a line, and even wrap to the next line. This output looks unprofessional. The following text appears on the same line: Reminder: 10 min
# before

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Program correctness includes correctly formatted output.
#
# **1.** The programmer on the left intentionally inserted a newline in the first sentence, namely "Kia Smith ... video meeting". Why?
# - Probably a mistake
# - So the text appears less jagged ✓
# - To provide some randomness to the output
# *The two resulting lines are closer to the same length, which may look more appealing to a reader. On the right, the text  wraps when reaching the end, which isn't as neat.*
#
# **2.** The programmer on the right side did not end the first sentence with a newline. What effect did that omission have?
# - "Join meeting" appears on the same line. ✓
# - No effect
# *On the left, "Join meeting" is clearly visible due to a preceding blank line. But on the right, "Join meeting" is easy to miss, appearing directly after the previous sentence.*
#
# **3.** The programmer on the left neatly formatted the link, the "Phone:" text, and phone numbers. What did the programmer on the right side do?
# - Also neatly formatted those items.
# - Output those items without neatly formatting. ✓
# *The output on the right is not neatly formatted. The link is harder to see, and "Phone" is in the wrong place due to a missing newline.*
#
# **4.** On the right, why did the "Reminder..." text appear on the same line as the separator text "------"?
# - Because programs behave erratically.
# - Because the programmer didn't end the output with a newline. ✓
# *Programs should almost always end with a newline, so that any subsequent text appears on a separate line. Here, not only does the next text "Reminder..." appear on the same line (which looks bad), but that text also wraps, making the text even harder to read.*
#
# **5.** Whitespace _____ important in program output.
# - is ✓
# - is not
# *Learners often want to ignore whitespace, but most programs that have output must take care to create neat output, with spaces and newlines carefully placed (and usually ending with a newline).*

# %% [markdown]
# ### Programming is all about precision
#
# Programming is all about *precision*. Programs must be created precisely to run correctly. Ex:

# %% [markdown]
# - = and == have different meanings.
# - Using i where j was meant can yield a hard-to-find bug.
#
# - Not considering that n could be 0 in sum/n can cause a program to fail entirely in rare but not insignificant cases.
#
# - Counting from i being 0 to i < 10 vs. i <= 10 can mean the difference between correct output and a program outputting garbage.
#
# In programming, every little detail counts. Programmers must pay extreme *attention to detail*.
#
# Thus, another reason for caring about whitespace in program output is to help new programmers get into a "precision" mindset when programming. Paying careful attention to details like whitespace instructions, carefully examining feedback regarding whitespace differences, and then modifying a program to exactly match expected whitespace  are exercises that strengthen attention to detail. Such attention can lead programmers to make fewer mistakes when creating programs, spend less time debugging, and instead create programs that work correctly.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Thinking precisely, and attention to detail.
#
# **1.** How many times is the letter F (any case) in the following?
#
# If Fred is from a part of France, then of course Fred's French is good.
# Answer: 8
# *Hint: Count the fs and Fs. Don't forget the fs in "of".*
# *Each occurrence of the letter F has been bolded: I**f** **F**red is **f**rom a part o**f** **F**rance, then o**f** course **F**red's **F**rench is good.
# Some people miss the fs in "of" because the f sounds like a v there.*
#
# **2.** How many differences are in these two lines?
#
# Printing A linE is done using println
#
# Printing A linE is done using print1n
# Answer: 1
# *Hint: Look for any difference in letters, spaces, and punctuation.*
# *Although the capitalization of A and line is odd, the instructions asked for differences, not errors. The first println has a lowercase L (l), and the second print1n has the number 1. This error is common among people learning certain programming languages: Not noticing that a name uses a lowercase letter L (l) vs. an uppercase I (L.) vs. a number 1.*
#
# **3.** How many typos are in the following?
#
# Keep calmn and cary on.
# Answer: 2
# *Hint: "calmn" is one typo. Any other typos?*
# *The correct saying is, "Keep calm and carry on."  Thus, calmn should be calm, and cary should be carry.*
#
# **4.** If I and E are adjacent, I should come before E, except after C (where E should come before I). How many violations are in the following?
#
# BEIL CEIL ZIEL YIEIK TREIL
# Answer: 3
# *Hint: Any EI is a violation, unless coming after C. So BEIL is a violation, while CEIL is not. Any other violations?*
# *Any EI is a violation, unless coming after C.
# BEIL: Violation
# CEIL: I isn't before E, but OK because after C.
# ZIEL: I comes before E, so OK.
# YIEIK: The first IE is OK. But, that E is involved in EI, which is a violation.
# TREIL: Violation.*
#
# **5.** A password must start with a letter, be at least six characters long, include a number  and  a special symbol, but not include any whitespace. How many of the following passwords are valid?
#
# hello goodbye Maker1 dog!three Oops_again 1augh#3
# Answer: 0
# *Hint: Are any valid?*
# *Not a single password meets all the rules.
# hello is less than 6 characters.
# goodbye lacks a number or symbol.
# Maker1 lacks a symbol.
# dog!three lacks a number.
# Oops_again lacks a number.
# 1augh#3 doesn't start with a letter (the first character is the number 1, not letter l).*

# %% [markdown]
# ### CHALLENGE ACTIVITY: Identifying whitespace issues and typos.

# %% [markdown]
# > The focus needed to answer the above correctly is the kind of focus needed to write correct programs. Due to this fact, some employers give "attention to detail" tests to people applying for programming positions.  To see sample tests, perform a web search on "programmer attention to details".
