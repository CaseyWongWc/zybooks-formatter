# %% [markdown]
# ## 1.5 Integrated development environment

# %% [markdown]
# ### Introduction to IDEs
#
# When developing software, a programmer must write, run, test, and debug code. Each of these tasks can be performed with different software. Ex: A text editor is needed to write code, and a Python interpreter is needed to run the code. An integrated development environment (IDE) is software that integrates a text editor and a Python interpreter, often with additional tools. Ex: Most IDEs include the ability to edit multiple files, a file manager for finding and organizing files, shortcut buttons, a debugger to help a programmer find bugs, and a console for entering commands and executing programs.
#
# IDEs support multiple programming languages and are widely used in software development. IDLE is the official IDE included with most installations of the Python language.  Other common IDEs for Python include Visual Studio Code, PyCharm, and XCode.
#
# Most IDEs do not come pre-installed with an operating system and must be installed separately. Some IDEs are run locally on a computer, while others are cloud-based and are run using a web browser.

# %% [markdown]
# > **PyCharm, an IDE for Python.**

# %% [markdown]
# ### PARTICIPATION ACTIVITY: An IDE integrates various programming tools.
#
# Step 1: A text editor containing Python code appears. The file is named main.py. The text editor is labeled Text editor Python interpreter not shown.
# Step 2: A tab indicating a file called functions.py appears next to the main.py tab. The new tab is labeled Tabs for multiple files. A new pane labeled File manager appears to the left and contains a file structure with the location of the two files.
# Step 3: A new pane with icons and labeled Shortcut buttons appears to the lower left. A new pane labeled Debugger appears with the words Variables and Breakpoints. A new pane labeled Console appears.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: IDEs.
#
# **1.** What does IDE stand for?
# - Identity environment
# - Integrated development environment ✓
# - Integrated development executable
# *An IDE is a software environment that integrates various tools to make software development easier and more efficient.*
#
# **2.** Which software is necessary when programming either with or without an IDE?
# - Text editor only
# - Text editor and Python interpreter ✓
# - Text editor, Python interpreter, and debugger
# *A programmer uses a text editor to create the source file and a Python interpreter to run the source file. Thus, an IDE must include a text editor and Python interpreter at minimum.*
#
# **3.** Which of the following is an advantage of using an IDE?
# - Fewer steps are needed when running a program using an IDE. ✓
# - An IDE uses less memory and fewer system resources than separate tools.
# - An IDE is less expensive than separate tools.
# *An IDE provides the ability to rapidly run code. Without an IDE, a programmer must manually run the source file in a Python interpreter. An IDE usually provides a shortcut button that automatically runs a Python program.*

# %% [markdown]
# ### Common features of an IDE
#
# IDEs contain many features that can make programming more efficient and convenient. Common IDE features include the following.
#
# - Syntax highlighting uses different colors for keywords, variables, strings, and other code syntax elements. Syntax highlighting can help a programmer identify errors such as unclosed quotes and parentheses, missing colons, and misspellings.
# - Automatic delimiter completion adds a matching closing quotation mark, parenthesis, bracket, or brace when a corresponding opening symbol is typed, which can help errors be more easily identified.
#
# - Shortcut buttons allow various predefined operations to be performed with a single click. Ex: A common shortcut button allows a program to be run quickly without having to enter a command to pass the source file to the Python interpreter.
# - A file manager and multiple text editor tabs for separate files allow different programs, input files, and output files to be easily accessed and edited.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Common features of an IDE.
#
# Static code:
# Begin Python code:
# wage = 20
# print("Salary is", wage * 40 * 52)
# End Python code.
#
# Console in IDE:
# Running program...
# Salary is 41600
#
# Step 1: An IDE shows two files being edited, main.py and functions.py, in the file manager. The current tab is main.py with code up to print. A mouse pointer clicks functions.py in the file manager. The active tab changes from main.py to functions.py with different code. The mouse pointer clicks main.py in the file manager. The active tab changes back to main.py.
# Step 2: A green box appears around print and 20 in the code. A black box appears around wage.
# Step 3: The mouse pointer clicks next to print and a cursor appears. A ( is added and a ) appears at the same time next to it.
# Step 4: The code print("Salary is, wage * 40 * 52) appears. All code to the right of the quotation mark is in red. The label Wrong colors appears.
# Step 5: The cursor moves to after "is" and a quotation mark is added. All code to the right of the quotation mark reverts to the correct colors. The label Wrong colors disappears.
# Step 6: The mouse pointer clicks a play button. Running program appears in the console. Salary is 41600 appears in the console.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Common features of an IDE.
#
# **1.** What is syntax highlighting?
# - Automatic correction of syntax errors
# - Appearance of different code elements in different colors ✓
# - Addition of the matching closing parenthesis when an open parenthesis is typed
# *Syntax highlighting uses  different colors to display different code elements. Ex: The following statement has five different types of code elements that each use a different color, namely the string literal "Salary is", the numbers 40 and 52, the symbols ( , * ), the variable name wage, and the function name print.

# %%
print("Salary is", wage * 40 * 52)

# %% [markdown]
# *
#
# **2.** In the animation above, the programmer was able to identify an error because of the wrong colors in the following line of code.

# %%
print("Salary is, wage * 40 * 52)

# %% [markdown]
# Use syntax highlighting to identify the error.
# - The function name print is misspelled.
# - The closing parenthesis at the end of the statement is missing.
# - A quotation mark is missing. ✓
# *The color of the code after the word "is" is the same color as the color of "Salary is", indicating that everything after the first quotation mark is being treated as part of a string literal. The programmer forgot to add a closing quotation mark between "is" and the comma.*
#
# **3.** In the animation above, the programmer switched to edit a different file by clicking a different filename in the file manager pane. How else could the programmer have switched between files?
# - By clicking the tabs along the top of the text editor ✓
# - By entering the filename in the console
# - By typing the filename in the text editor
# *Open files appear in tabs above the code window. Clicking on a tab switches the code window to view or edit the selected file.*

# %% [markdown]
# ### Console and command-line interface in an IDE
#
# An IDE typically includes a console for user input and program output. A console (or terminal) is a text-based interface that allows a user to run programs, enter input, and view program output.
#
# A console's command-line interface (CLI) is an interface that allows a user to enter commands to run programs and work with files. One advantage of a CLI is the ability to run a program with command-line arguments. A command-line argument is a value entered by a user after the program name when running a program from a command line. Ex: In the command `ls -a`, ls is the name of the program and -a is a command-line argument.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Console and command-line interface.
#
# Begin Python code.
# wage = int(input())
# print("Salary is", wage * 40 * 52)
# End Python code.
#
# Console in IDE:
# $ python3 main.py
# 25
# Salary is 52000
# $
#
# Step 1: An IDE shows Python code. The file manager contains the file main.py. The console button is clicked. The user enters python3 main.py into the console. The label Command for running the source file appears. python3 is labeled Executable program and main.py is labeled Argument.
# Step 2: The cursor appears on the next line and the label Awaiting input appears. The user enters 25. The output Salary is 52000 appears and the label Output displayed appears. The console prompt $ appears again.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Console and command-line interface.
#
# **1.** Which of the following is displayed in a console?
# - Input only
# - Both input and output ✓
# - Output only
# *Both a program's output and the user's input to the program appear on the console. A programmer must examine a program carefully to distinguish between output from a print statement and input entered by the user.*
#
# **2.** In the following command, what are the command-line arguments?
#
# `python3 main.py 0.5 25`
# - python3
# - python3 main.py 0.5 25
# - main.py 0.5 25 ✓
# *python3 is the executable program name, and main.py 0.5 25 are specific command-line arguments that change how python3 runs. Different executable programs accept different command-line arguments.*
#
# **3.** What is an advantage of running a program through a CLI in an IDE?
# - A CLI allows a program to easily be run with arguments. ✓
# - Using the CLI to run a program is faster than using the shortcut button in the IDE.
# - The Python interpreter is not required when running a program through the CLI.
# *The CLI allows a program to be run with command-line arguments, which can be used to change how the program runs. Without a CLI, any arguments for the program must be pre-specified by editing IDE-specific configurations.*
