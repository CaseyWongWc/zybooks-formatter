# %% [markdown]
# # bye
#
# **Class:** bye
#
# **Exported:** 4/9/2026, 7:40:47 PM
#
# ---
#
# ### 4/9/2026, 7:37:07 PM
#
# ![pasted-1775788626083.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/c62d6a26-eb26-4377-bef2-ca7d92373f42)
#
# **OCR Text:**
#
# **EXTRACTED TEXT:**

# %%
Python Class
Nhi Nguyen
Confidential

# %% [markdown]
# **DESCRIBE VISUALS:**
#
# The image features a title slide for a Python class presentation. It includes a logo of Python along with a cartoon snake character, which symbolizes the Python programming language. There are various small images surrounding the main title, depicting people engaging with tech-related activities, such as coding and web design.
#
# **KEY CONCEPTS:**
#
# - Python programming language
# - Class or course presentation
# - Tech and coding activities
#
# ### 4/9/2026, 7:37:13 PM
#
# ![pasted-1775788632713.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/e2e61fbf-d313-4752-9e7d-aa2d2fb02383)
#
# ### 4/9/2026, 7:37:17 PM
#
# ![pasted-1775788636789.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/ebd7b9ba-ceb0-46e7-9b4d-d9b427922e8c)
#
# ### 4/9/2026, 7:37:24 PM
#
# ![pasted-1775788642854.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/3b96c2fa-aa36-461e-a487-0f38808c7fd0)
#
# **OCR Text:**
#
# 1. **EXTRACT TEXT:**

# %%
Python
   Attributes
   Confidential

# %% [markdown]
# 2. **DESCRIBE VISUALS:**
#    The image contains several small visuals, including people working with computers, documents, design interfaces, and coding elements. The overall design features a clean layout with colorful frames around each visual.
#
# 3. **KEY CONCEPTS:**
#    - Python
#    - Attributes
#
# ### 4/9/2026, 7:37:28 PM
#
# ![pasted-1775788647173.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/d5cf6807-9ea5-4f1d-96ea-1479c6990e37)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Python Attributes

In Python, attributes are properties associated with an object or a class, accessible using dot notation (e.g., object.attribute). They store data and define the state of an object.

There are 2 types of attributes:

[1] Class Attributes:
Class attributes are variables that are shared among all instances of a class. They belong to the class itself, not a specific instance, and are useful for storing data that should be the same for every object, such as a default value or a constant.

[2] Instance Attributes
Instance attributes are unique to each individual object (instance) created from a class. They define the specific characteristics of an object and can have different values for different instances of the same class.

# %% [markdown]
# ### Describe Visuals:
# The image contains a structured text layout, presenting information about Python attributes, without any diagrams, charts, or graphs.
#
# ### Key Concepts:
# - Attributes in Python
# - Class Attributes
# - Instance Attributes
#
# ### 4/9/2026, 7:37:35 PM
#
# ![pasted-1775788654635.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/09eb3bcc-3d19-4487-a60b-0a8a21014e7a)
#
# **OCR Text:**
#
# ### Extracted Text:
# Python Class Attributes
# 1. They are defined within the class body, but outside of any instance methods (like `__init__`).
# 2. Scope: They are shared across all instances, using a single memory location.
# 3. Access: They can be accessed using either the class name or any instance of the class (e.g., Car.wheels or car1.wheels).
# 4. Modification: Modifying a class attribute through the class name affects all instances, while modifying it through an instance creates a new instance attribute that "shadows" the class attribute for that specific instance.
#
# ### Key Concepts:
# - Class attributes
# - Scope and memory location
# - Access methods
# - Modification of attributes in instances vs. class level
#
# ### 4/9/2026, 7:37:41 PM
#
# ![pasted-1775788660012.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/247c60a1-9330-4040-a96b-858256e058c8)
#
# **OCR Text:**
#
# **1. EXTRACT TEXT:**

# %%
Python Class Attributes

class Dog:
    # class attribute
    age = 1

dog1 = Dog()
dog2 = Dog()

print(dog1.age)  # 100
print(dog2.age)  # 100
print(Dog.age)   # 100

# %% [markdown]
# **2. DESCRIBE VISUALS:**
# The image features a code snippet illustrating a Python class named `Dog`, which includes a class attribute named `age`. It shows the creation of two instances of the `Dog` class and how the class attribute is accessed.
#
# **3. KEY CONCEPTS:**
# - Class attributes in Python
# - Instance creation
# - Accessing class attributes through instances and the class itself
#
# ### 4/9/2026, 7:37:46 PM
#
# ![pasted-1775788665472.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/b75e8916-59b7-40f3-ab51-84e703bf6a99)
#
# **OCR Text:**
#
# ### EXTRACTED TEXT:

# %%
Modify Immutable Class Attributes

class Dog:
    # class attribute
    age = 1

dog1 = Dog()
dog2 = Dog()
Dog.age = 100  # modify class attribute
print(dog1.age) # 100
print(dog2.age) # 100
print(Dog.age)  # 100

NOTE: Changes to a class attribute will affect all instances
of the class, as they share the same class attribute

# %% [markdown]
# ### VISUALS DESCRIPTION:
# The image contains code illustrating the modification of a class attribute in a Python class called `Dog`. It shows two instances (`dog1` and `dog2`) of the class, and how changing the class attribute `age` affects both instances.
#
# ### KEY CONCEPTS:
# - Immutable class attributes
# - Influence of class attributes on instances
# - Syntax for modifying class attributes
#
# ### 4/9/2026, 7:37:49 PM
#
# ![pasted-1775788668825.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/bf1cf0df-6cdd-4557-923f-b08dfaa105fd)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Modify Immutable Class Attributes

class Dog:
    # class attribute
    age = 1

dog1 = Dog()
dog2 = Dog()

dog1.age = 10  # override value of the instance attribute
                # but NOT the class attribute

print(dog1.age)  # 10
print(dog2.age)  # STILL 1
print(Dog.age)   # STILL 1

NOTE: Changes to a class attribute will affect all instances of the class, as they share the same class attribute unless it is overridden by an instance attribute.

# %% [markdown]
# ### Visual Description:
# The image contains a code snippet illustrating a class definition in Python, specifically showcasing how to modify an instance's attribute while retaining the original class attribute.
#
# ### Key Concepts:
# - Class attributes vs. instance attributes
# - Override of instance attributes
# - Impact of class attribute changes on instances
#
# ### 4/9/2026, 7:37:53 PM
#
# ![pasted-1775788672543.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/fa529078-bb97-4445-9cdf-565238b1fc02)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Modify Mutable Class Attributes

class Bag:
    items = []  # class attribute

b1 = Bag()
b2 = Bag()

b1.items.append("apple")

print(b1.items)  # ['apple']
print(b2.items)  # ['apple']
print(Bag.items)  # ['apple']

List is a mutable object. Thus,
The items list is created once, and all instances of the Bag class will point to the same list in memory

b1.items
    └──> SAME LIST items []
b2.items

How to fix it? turn the mutable object to be an instance attribute, instead

# %% [markdown]
# ### Description of Visuals:
# The image contains a code snippet demonstrating a Python class named `Bag` with a mutable class attribute `items`. It shows the unintended behavior of instances sharing the same list, along with a visual indicating that both instances point to the same list in memory.
#
# ### Key Concepts:
# - Mutable class attributes
# - Instance attributes vs. class attributes
# - Shared state between class instances
#
# ### 4/9/2026, 7:37:57 PM
#
# ![pasted-1775788676266.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/63b5c1a7-573b-4268-8e3c-cb9aab161460)
#
# **OCR Text:**
#
# **EXTRACTED TEXT:**
#
# Modify Class Attributes
#
# NOTE:
# Changes to a class attribute will affect all instances of the class, as they share the same class attribute unless it is overridden by an instance attribute. However, if the class attribute is a mutable object (e.g., list, dictionary, set), modifying it will affect all instances.
#
# **KEY CONCEPTS:**
# - Class attributes
# - Instance attributes
# - Mutable objects (list, dictionary, set)
#
# ### 4/9/2026, 7:37:59 PM
#
# ![pasted-1775788678603.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/1529a2e1-df1f-4441-8d3d-da0582dc0773)
#
# **OCR Text:**
#
# ### EXTRACTED TEXT:

# %%
Class Activity
What will be the output of running the following code?

class B:
    num = 4
b = B()
b.num = 2
print(num)

Answer: C. 10
A. 6
B. 1
C. 10
D. None

• num = 10 is a global variable
  It exists outside the class and is accessible everywhere
• num = 4 inside the class B is a class variable
• b.num = 2 creates an instance variable
  This overrides the class variable only for that object (b)
• print(num) refers to the global num, which is still 10

# %% [markdown]
# ### VISUAL DESCRIPTION:
# The image features a class activity layout with code involving variable scopes in Python. It illustrates how global and instance variables function within a class structure.
#
# ### KEY CONCEPTS:
# - Global variable vs. class variable vs. instance variable
# - Variable scope in Python
# - Output of code based on variable assignment and scope
#
# ### 4/9/2026, 7:38:02 PM
#
# ![pasted-1775788681451.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/c3b70305-c52a-4019-a7df-f5977dc779c9)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Class Activity
What will be the output of running the following code?

obj = MyClass()

class MyClass:
    count = 5
    print("Hello from MyClass!")

another = MyClass()
print(obj.count)

A.3  B.Error  C.5  D.None

Answer: B. Error

obj = MyClass() # ← problem happens here. At this point:
- Python has not yet seen the class definition
- MyClass does not exist yet

So, this line immediately causes an error.

# %% [markdown]
# ### Description of Visuals:
# The image presents a programming example in Python, showing a scenario where an error occurs when trying to instantiate a class before its definition.
#
# ### Key Concepts:
# - Class Instantiation
# - Python Error Handling
# - Scope and Definition Timing
#
# ### 4/9/2026, 7:38:05 PM
#
# ![pasted-1775788684499.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/20661c9c-4010-4377-b7df-bb5177c59eff)
#
# **OCR Text:**
#
# ### Extracted Text:
# Instance Attribute
#
# 1. Definition: They are typically defined within the class's initializer method (or constructor), __init__, using the self keyword (e.g., self.name = name).
# 2. Scope: Each instance has its own copy of the instance attribute in memory.
# 3. Access: They are accessed using the instance object (e.g., dog.name).
# 4. Modification: Changing an instance attribute only affects that specific instance.
#
# ### Key Concepts:
# - Instance attributes
# - Definition and initialization
# - Scope and access of instance attributes
# - Modification effects on specific instances
#
# ### 4/9/2026, 7:38:08 PM
#
# ![pasted-1775788687334.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/ff930363-42d6-4651-94a2-26d1f1e2125b)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Instance Attribute Example
class Dog:
    def __init__(self, name):
        self.name = name # instance attribute

d1 = Dog("Buddy")
d2 = Dog("Max")

print(d1.name) # Buddy
print(d2.name) # Max

Class attribute = shared among all objects
Instance attribute = unique per object

# %% [markdown]
# ### Visuals Description:
# The image contains code illustrating the concept of instance attributes in Python. It shows a class definition for `Dog`, creating two instances with unique names, and demonstrates printing these names.
#
# ### Key Concepts:
# - **Instance Attribute**: Attributes unique to each object instance.
# - **Class Attribute**: Attributes shared among all instances of a class.
#
# ### 4/9/2026, 7:38:13 PM
#
# ![pasted-1775788692032.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/5aace041-6e68-46e0-bc3e-c9ab078e8070)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Constructor
class Dog:
    def __init__(self, name): # constructor
        self.name = name # instance attribute

d1 = Dog("Buddy")

__init__ in Python is a special method (also known as a constructor) that runs automatically when you create a new object from a class. It set up its initial state of an object.

self is a convention for self-reference by the instance object.

Explain the code
__init__ is automatically called by Python when Dog("Buddy") runs
- "Buddy" is passed into __init__
- self.name store the value in the object

# %% [markdown]
# ### Visual Description:
# The image includes a code snippet defining a Python class called `Dog` with a constructor method (`__init__`). The code illustrates how to instantiate an object of the `Dog` class.
#
# ### Key Concepts:
# - Python constructor (`__init__` method)
# - Object instantiation
# - Instance attribute assignment
#
# ### 4/9/2026, 7:38:17 PM
#
# ![pasted-1775788696271.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/25384cc1-dd3d-4031-ab5b-c4a1d2f229c8)
#
# **OCR Text:**
#
# **1. EXTRACT TEXT:**

# %%
Instance Attribute Example
How to Avoid the Problem with modifying mutable class attribute?
Ans: Using instance attribute

class Bag:
    def __init__(self):
        self.items = [] # separate list per object

b1 = Bag()
b2 = Bag()

b1.items.append("apple")
print(b1.items) # ['apple']
print(b2.items) # []

# %% [markdown]
# **2. DESCRIBE VISUALS:**
# The image features a code snippet illustrating the concept of instance attributes in Python. It demonstrates how to create separate lists for different instances of a class to avoid altering shared mutable class attributes.
#
# **3. KEY CONCEPTS:**
# - Instance attributes
# - Mutable class attribute
# - Object-oriented programming in Python
#
# ### 4/9/2026, 7:38:23 PM
#
# ![pasted-1775788701950.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/5cd0078c-a6d7-448a-9324-67daac4b2e93)
#
# **OCR Text:**
#
# **EXTRACT TEXT:**

# %%
Python
Methods
Confidential

# %% [markdown]
# **DESCRIBE VISUALS:**
# The image includes a title on Python methods and several small visual elements or images of people working with technology, coding, and design materials.
#
# **KEY CONCEPTS:**
# - Python Methods
# - Coding
# - Design
#
# ### 4/9/2026, 7:38:25 PM
#
# ![pasted-1775788704465.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/a62fe012-306e-45aa-8c16-a01cdc965b6e)
#
# **OCR Text:**
#
# ### Extracted Text:
# **Instance Methods**
# An instance method is a function defined inside a class that works with a specific object (instance) of that class.
#
# - **Self parameter:** instance methods always take self as its first parameter. When the method is called on an instance (e.g., my_bject.my_method()), Python automatically passes that instance object as the first argument to the self parameter.
#
# - **Access to instance data:** The self parameter allows the method to access and manipulate the instance's attributes, which are unique to that particular object.
#
# - **Access to class data:** Instance methods can also access class attributes using self.__myClass__.__class_attribute or by directly referencing the class name such as myClass.class_attribute, allowing them to potentially modify the class state as well.
#
# ### Visuals Description:
# There are no diagrams, charts, equations, or drawings in the image; it is text-based.
#
# ### Key Concepts:
# - Instance methods
# - Self parameter
# - Access to instance and class data
#
# ### 4/9/2026, 7:38:31 PM
#
# ![pasted-1775788710712.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/35436d5a-05ce-4400-bd8a-ef90e576841f)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Instance Method Example 1

class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):  # instance method
        print(f'{self.name} says woof!')

d1 = Dog("Buddy")
d1.bark()

# %% [markdown]
# ### Description of Visuals:
# The image contains code showing a Python class definition for a `Dog`. It includes an `__init__` method for initializing the dog's name and a `bark` method that prints a message when called.
#
# ### Key Concepts:
# - Class definition in Python
# - Instance methods
# - Object instantiation and method calling
#
# ### 4/9/2026, 7:38:36 PM
#
# ![pasted-1775788715368.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/51b61000-5bce-4f04-a87d-4f7c17a4b88a)
#
# ### 4/9/2026, 7:38:39 PM
#
# ![pasted-1775788718701.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/5544ab6e-57b3-4ecc-ab5c-a408f69c3efd)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Instance Method Example

class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"New balance: {self.balance}")

acc = BankAccount(100)
acc.deposit(50)

# %% [markdown]
# ### Description of Visuals:
# The image presents a code snippet illustrating the implementation of a Python class named `BankAccount`, demonstrating how to define an instance method for depositing money into a bank account.
#
# ### Key Concepts:
# - Instance Methods
# - Class Definition in Python
# - Object-Oriented Programming (OOP)
#
# ### 4/9/2026, 7:38:42 PM
#
# ![pasted-1775788721318.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/8b424608-d045-4dbe-a5ec-d945e12cc1ec)
#
# **OCR Text:**
#
# ### Extracted Text:

# %%
Instance Method Example
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            return "Deposit must be positive"
        self.balance += amount
        return f"New balance: {self.balance}"

    def withdraw(self, amount):
        if amount <= 0:
            return "Withdrawal must be positive"
        if amount > self.balance:
            return "Invalid transaction"

        self.balance -= amount
        return f"New balance: {self.balance}"

acc = BankAccount(100)
print(acc.deposit(50))
print(acc.withdraw(30))

# %% [markdown]
# ### Describe Visuals:
# The image contains Python code demonstrating a class named `BankAccount` which includes methods for depositing and withdrawing money, as well as handling errors like negative amounts and insufficient balance.
#
# ### Key Concepts:
# - Instance methods in Python
# - Error handling in banking transactions
# - Class construction and attributes
#
# ### 4/9/2026, 7:38:45 PM
#
# ![pasted-1775788724588.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/a096501c-c747-4d3c-a6e1-8bd01691b888)
#
# ### 4/9/2026, 7:38:48 PM
#
# ![pasted-1775788727552.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/cc55608a-6825-464c-9031-24ca5c156a84)
#
# ### 4/9/2026, 7:38:51 PM
#
# ![pasted-1775788730262.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/7b9f5a47-4803-45dd-bedb-2e642acefb75)
#
# ### 4/9/2026, 7:38:53 PM
#
# ![pasted-1775788732841.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/4a9c92b9-7b5b-43ef-80a4-e58b73096b09)
#
# **OCR Text:**
#
# **Extracted Text:**

# %%
Object as a Parameter

class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def areaDifference(self, anotherRec):
        diff = abs(self.area() - anotherRec.area())
        return diff

r1 = Rectangle(4, 3)
r2 = Rectangle(2, 1)
diffArea = r1.areaDifference(r2)
print(diffArea) # 10

# %% [markdown]
# **Description of Visuals:**
# The image contains code for a `Rectangle` class in Python that demonstrates how to calculate the area of rectangles and how to find the difference between the areas of two rectangle objects. It includes a constructor, methods for calculating area, and finding the area difference.
#
# **Key Concepts:**
# - Object-oriented programming with classes and methods.
# - Using parameters in class methods.
# - Calculating area and area differences between objects.

# %% [markdown]
# ### 4/9/2026, 7:38:58 PM
#
# ![pasted-1775788737909.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/18002740-4497-4502-844c-f57f5acb9e78)
#
# **OCR Text:**
#
# **Extracted Text:**
#
# Class Activity
# Zybooks: 28.20 LAB: Swap two numbers
#
# ---
#
# **Key Concepts:**
# - Swapping numbers
# - Zybooks programming lab

# %% [markdown]
# ### 4/9/2026, 7:39:02 PM
#
# ![pasted-1775788741280.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/f1faf2b9-503a-4456-a8e4-cbdf0eba569c)

# %% [markdown]
# ### 4/9/2026, 7:39:05 PM
#
# ![pasted-1775788744246.png](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/d365f9dc-304c-4065-8d87-5d8217ad56ab)
