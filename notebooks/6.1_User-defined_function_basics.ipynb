# %% [markdown]
# ## 6.1 User-defined function basics
#
# ### Functions (general)
#
# A program may perform the same operation repeatedly, causing a large and confusing program due to redundancy. Program redundancy can be reduced by creating a grouping of predefined statements for  repeated operations, known as a function. Even without redundancy, functions can prevent a main program from becoming large and confusing.
#
# ### CHALLENGE ACTIVITY
#
# Main programc1 = (f1 - 32.0) * (5.0 / 9.0)c2 = (f2 - 32.0) * (5.0 / 9.0)Main programc1 = F2C(f1)F2C(f)c = (f - 32.0) * (5.0 / 9.0)return cc2 = F2C(f2)c3 = F2C(f3)Simplera = expression1b = a + expression2c = b * expression3c = XYZ(a, b)d = expression1e = d + expression2f = e * expression3f = XYZ(d, e)Main programMain programa = expression1b = a + expression2c = b * expression3c = XYZ(a, b)d = expression4e = d * d * df = (e + 1) * 2f = CalcPQR(d, e, g)Main programMain programf = f / gXYZXYZXYZCalcPQRCluttered
# Repeated code
# Oops, error in third calculation.
# c3 = (f3 + 32.0) * (5.0 / 9.0)Calculation only
# written once
#
# Commonly, a program performs the same operation, such as a calculation, in multiple places. Here, the Fahrenheit to Celsius calculation is done in three places.
#
# Repeated operations clutter the main program and are more prone to errors.
#
# A better approach defines the Fahrenheit to Celsius calculation once, named F2C. Then, F2C can be "called" three times, yielding a simpler main program.
#
# The impact is  greater when the operation has multiple statements - here three statements but often tens of statements. The main program is much simpler.
#
# Even without repeated  operations, calling predefined operations keeps the main program simple and intuitive.
#
# Static figure: Three code blocks are displayed, a main program, a function program, and a simplified version of the main program.
# Main program
# Begin Python code:
#     c1 = (f1 - 32.0) * (5.0 / 9.0)
#     c2 = (f2 - 32.0) * (5.0 / 9.0)
#     c3 = (f3 + 32.0) * (5.0 / 9.0)
# End Python code.
#
# Begin Python code:
#     c = (f - 32.0) * (5.0 / 9.0)
#     return c
# End Python code.
#
# Main program
# Begin Python code:
#     c1 = F2C(f1)
#     c2 = F2C(f2)
#     c3 = F2C(f3)
# End Python code.
#
# Step 1: Commonly, a program performs the same operation, such as a calculation, in multiple places. Here, the Fahrenheit to Celsius calculation is done in three places.
# Main program
#     c1 = (f1 - 32.0) * (5.0 / 9.0)
#     c2 = (f2 - 32.0) * (5.0 / 9.0)
#     c3 = (f3 + 32.0) * (5.0 / 9.0)
#
# Step 2: Repeated operations clutter the main program and are more prone to errors. The main program code is cluttered and has repeated code. In addition, the calculation for c3 has an error that uses the wrong operation.
#
# Step 3: A better approach defines the Fahrenheit to Celsius calculation once, named F2C. Then, F2C can be "called" three times, yielding a simpler main program. A function is defined where the calculation is only written once.
# F2C(f)
#     c = (f - 32.0) * (5.0 / 9.0)
#     return c
#
# The simpler version of the main program code becomes
#     c1 = F2C(f1)
#     c2 = F2C(f2)
#     c3 = F2C(f3)
#
# Step 4: The impact is greater when the operation has multiple statements - here three statements but often tens of statements. The main program is much simpler. Two blocks appear, the first block titled Main program contains the code:
# a = expression1
# b = a + expression2
# c = b * expression3
#
# d = expression1
# e = d + expression2
# f = e * expression3
# The label XYZ appears next to variables a, b, and c, and again next to variables d, e, and f.
# The second block titled Main program contains the simpler code using a function:
# c = XYZ(a, b)
# f = XYZ(d, e)
#
# Step 5: Even without repeated operations, calling predefined operations keeps the main program simple and intuitive. Two blocks appear, the first block titled Main program contains the code:
# a = expression1
# b = a + expression2
# c = b * expression3
#
# d = expression4
# e = d * d * d
# f = (e + 1) * 2
# f = f / g
# The label XYZ appears next to variables a, b, and c. The label CalcPQR appears next to variables d, e, and f.
# The second block titled Main program contains the simpler code:
# c = XYZ(a, b)
# f = CalcPQR(d, e, g)
#
# ### PARTICIPATION ACTIVITY
#
# In the original main program, the Fahrenheit to Celsius calculation appeared how many times?
#
# 1. Although the Fahrenheit to Celsius calculation is always the same, that calculation appeared more than 1 time.
# 2. The main program has three statements, with each statement performing the Fahrenheit to Celsius calculation, using different variables in each statement. The repeated calculation clutters the main program and contains an error. The revised program uses the predefined F2C  to yield a much simpler main.
#
# Along with yielding a simpler main program, using the predefined Fahrenheit to Celsius calculation prevented what error in the original program?
#
# 1. Adding rather than subtracting 32.0
# 2. Multiplying by 9.0 / 5.0 rather than by 5.0 / 9.0
#
# In the last example above, the main program was simplified by _____.
#
# 1. eliminating redundant code for operation XYZ
# 2. predefining operations for XYZ and CalcPQR
#
# ### Function basics
#
# A function is a named series of statements.
#
#     - A function definition consists of the function's name and a block of statements. Ex: `def calc_pizza_area():` is followed by an indented block of statements.
#     - A function call is an invocation of the function's name, causing the function's statements to execute.
#
#  Python comes with a number of built-in functions, such as `input()`, `int()`, `len()`, etc. The def keyword is used to create new functions.
#
#  The function call calc_pizza_area() in the animation below causes execution to jump to the function's statements. Execution returns to the original location after executing the function's last statement.
#
#  Good practice is to follow the convention of naming functions with lowercase letters and underscores, such as get_name or calc_area.
#
#  Other aspects of function definition, like the (), are discussed later.
#
# ### CHALLENGE ACTIVITY

# %%
def calc_pizza_area():
 pi_val = 3.14159265

 pizza_diameter = 12.0
 pizza_radius = pizza_diameter / 2.0
 pizza_area = pi_val * pizza_radius * pizza_radius
 return pizza_area

print(f"{12:.1f} inch pizza is {calc_pizza_area():.3f}
  square inches")

# %% [markdown]
# 12.0 inch pizza is 113.097 square inches
# 12.016.0 inch pizza is 201.062 square inches
# 16.0
#
# The function call to calc_pizza_area() jumps execution to the function&apos;s statements.After the last statement of the calc_pizza_area() function, execution returns to the original location and the area of the pizza is returned and printed.
#
# Static figure:
# Begin Python code:
# def calc_pizza_area():
#     pi_val = 3.14159265
#
#     pizza_diameter = 12.0
#     pizza_radius = pizza_diameter / 2.0
#     pizza_area = pi_val * pizza_radius * pizza_radius
#     return pizza_area
#
# print(f"{12:.1f} inch pizza is {calc_pizza_area():.3f} square inches")
# End Python code.
#
# Step 1: The function call to calc_pizza_area() jumps execution to the function's statements. Each line within the calc_pizza_area function is highlighted one by one in order, up to return pizza_area.
#
# Step 2: After the last statement of the calc_pizza_area() function, execution returns to the original location and the area of the pizza is returned and printed. A monitor displays the print statement, stating 12.0 inch pizza is 113.097 square inches.
#
# ### PARTICIPATION ACTIVITY
#
# How many function calls to calc_pizza_area() exist?
#
# 1. 2
#
# How many function definitions of calc_pizza_area() exist?
#
# 1. 1
#
# How many output statements would execute in total?
#
# 1. 2
#
# How many print statements exist in calc_pizza_area()?
#
# 1. 0
#
# ### CHALLENGE ACTIVITY
#
# python-tutor-v5
#
# def get_face():
#    face_char = "o   o\n  o\nooooo"
#    return face_char
#
# print("Say cheese!")
#
# print(get_face())
#
# print("Did it turn out ok?")
#
# Say cheese!
#
# Say cheese!
#
# get_face_f1
#
# Say cheese!
#
# get_face_f1
#
# Say cheese!
#
# get_face_f1
#
# o   o
#   o
# ooooo
#
# Say cheese!
#
# get_face_f1
#
# o   o
#   o
# ooooo
#
# o   o
#   o
# ooooo
#
# Say cheese!
# o   o
#   o
# ooooo
#
# Say cheese!
# o   o
#   o
# ooooo
# Did it turn out ok?
#
# A code trace showing the execution flow of the print_face() function from above. The code starts in the global scope, until the print_face() function call is execute, at which point the statements in the function are executed. After all print_face() statements have been executed, the program continues to execute code following the function call.
#
# ### CHALLENGE ACTIVITY
#
# get_pattern() returns 5 characters. Call get_pattern() twice in print() statements to return and print 10 characters. Example output:

# %%
*****
*****

# %% [markdown]
# ### Return statements
#
# A function may return one value using a return statement. Below, the compute_square() function returns the square of its argument.
#
# ### CHALLENGE ACTIVITY

# %%
def compute_square(num_to_square):
    return num_to_square * num_to_square

num_squared = compute_square(7)

print(f"7 squared is {num_squared}")

# %% [markdown]
# 7 squared is 4977 * 749
#
# Call compute_square and pass in the value 7.Compute the square of num_to_square and return the result.num_squared is assigned the return value of compute_square(7).
#
# Static figure:
# Begin Python code:
# def compute_square(num_to_square):
#     return num_to_square * num_to_square
#
# num_squared = compute_square(7)
# print(f"7 squared is {num_squared}")
# End Python code.
#
# Step 1: Call compute_square and pass in the value 7. Compute_square has one parameter named num_to_square.
# Step 2: Compute the square of num_to_square and return the result. The value passed to compute_square is 7, which is the value assigned to num_to_square. Compute_square returns num_to_square times num_to_square, so 7 times 7 is calculated, resulting in 49 as the return value.
# Step 3: num_squared is assigned the return value of compute_square(7). A monitor displays the print statement, stating 7 squared is 49.
#
# A function can return only one item, not two or more (though a list or a tuple with multiple elements could be returned). A function with no return statement, or a return statement with no following expression, returns the value `None`. None is a special keyword that indicates no value.
#
# A return statement may appear at any point in a function, not just as the last statement. A function may also contain multiple return statements in different locations.
#
# ### PARTICIPATION ACTIVITY
#
# Add a return statement to the function that returns the result of adding `num1` and `num2`.
#
# 1. num1 + num2
# 2. num1 + num2
#
# Add a return statement to the function that returns the cube of the argument, i.e. (`num*num*num`).
#
# 1. return num*num*num
# 2. return num**3
# 3. return (num**3)
# 4. return (num*num*num)
#
# ### Parameters
#
# A programmer can influence a function's behavior via an input.
#
# -   A parameter is a function input specified in a function definition. Ex: A pizza area function might have diameter as an input.
#
# -   An argument is a value provided to a function's parameter during a function call.  Ex: A pizza area function might be called as `calc_pizza_area(12.0)` or as `calc_pizza_area(16.0)`.
#
#  A parameter is like a variable definition. Upon entering the function, the parameter is bound to the argument object provided by the call, creating a shared reference to the object. Upon return, the parameter can no longer be used.
#
#
#  An argument may be an expression, like `12.0`, `x`, or  `x * 1.5`.
#
# ### CHALLENGE ACTIVITY
#
# python-tutor-v5
#
# import math
# def calc_pizza_area(pizza_diameter):
#    pizza_radius = pizza_diameter / 2.0
#    pizza_area = math.pi * pizza_radius * pizza_radius
#    return pizza_area
#
# print(f"12.0 inch pizza is {calc_pizza_area(12.0):.3f} square inches")
# print(f"16.0 inch pizza is {calc_pizza_area(16.0):.3f} square inches")
#
# calc_pizza_area(pizza_diameter)
#
# calc_pizza_area
#
# calc_pizza_area(pizza_diameter)
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_pizza_area(pizza_diameter)
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_pizza_area(pizza_diameter)
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f1
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# pizza_radius
#
# calc_pizza_area(pizza_diameter)
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f1
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# pizza_radius
#
# calc_pizza_area(pizza_diameter)
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f1
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# pizza_radius
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
#
# calc_pizza_area
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f2
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f2
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f2
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# pizza_radius
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f2
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# pizza_radius
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area
#
# calc_pizza_area_f2
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# pizza_radius
#
# calc_pizza_area(pizza_diameter)
#
# 12.0 inch pizza is 113.097 square inches
# 16.0 inch pizza is 201.062 square inches
#
# calc_pizza_area
#
# A print_pizza_area function is defined with a single parameter "pizza_diameter". That function is called twice with different values, showing how the function output changes depending on what value is provided as an argument.
#
# ### PARTICIPATION ACTIVITY
#
# Complete the function definition to have a parameter named num_grade.
#
# 1. num_grade
#
# Call a function named calc_calories() passing the value 21 as an argument.
#
# 1. calc_calories(21)
#
# Is the following a valid function definition beginning? Type yes or no.
# `def my_fct(userNum + 5): `
#
# 1. No
#
# Assume a function def get_birthday_age(user_age): simply returns the value of user_age + 1. What will the following code output?

# %%
print(get_birthday_age(42), get_birthday_age(20))

# %% [markdown]
# 1. 43 21
#
# ### Multiple or no parameters
#
# A function may have multiple parameters separated by commas. Parameters are assigned with argument values: First parameter with the first argument, second with the second, etc.
#
# A function definition with no parameters must still have the parentheses, as in: `def calc_something():`. The call to such a function must include parentheses and must be empty, as in: `calc_something()`.
#
# ecde0acf-527e-52cb-89e5-931fbcfb6471

# %%
def calc_pizza_volume(pizza_diameter, pizza_height):
   pi_val = 3.14159265

   pizza_radius = pizza_diameter / 2.0
   pizza_area = pi_val * pizza_radius * pizza_radius
   pizza_volume = pizza_area * pizza_height
   return pizza_volume

print(f"12.0 x 0.3 inch pizza is {calc_pizza_volume(12.0, 0.3):.3f} cubic inches.")

print(f"12.0 x 0.8 inch pizza is {calc_pizza_volume(12.0, 0.8):.3f} cubic inches.")

print(f"16.0 x 0.8 inch pizza is {calc_pizza_volume(16.0, 0.8):.3f} cubic inches.")

# %%
12.0 x 0.3 inch pizza is 33.929 cubic inches.
12.0 x 0.8 inch pizza is 90.478 cubic inches.
16.0 x 0.8 inch pizza is 160.850 cubic inches.

# %% [markdown]
# ### PARTICIPATION ACTIVITY
#
# Which answer correctly defines two parameters `x` and `y` for a function definition:
# `def calc_val(...):`?
#
# 1. (x; y)
# 2. A comma is required between parameters.
# 3. (x, y)
#
# Which answer correctly passes two integer arguments for the function call `calc_val(...)`?
#
# 1. (99, 44 + 5)
# 2. (99 + 44)
# 3. (99 44)
#
# Given a function definition:
# `def calc_val(a, b, c):`,
# b is assigned with what value during this function call:
# `calc_val(42, 55, 77)`?
#
# 1. Unknown
# 2. The first parameter a will be assigned with that first argument's value.
# 3. The second parameter b will be assigned with that second argument's value.
#
# Given a function  definition:
# `def calc_val(a, b, c):`
# and given variables i, j, and k, which are valid arguments in the call `calc_val(...)`?
#
# 1. (i, j)
# 2. (k, i + j, 99)
# 3. (i + j + k)
#
# ### PARTICIPATION ACTIVITY
#
# What will be returned for the following function call?
# ` compute_sum(1, 2)`
#
# 1. 3
#
# Write a function call using  compute_sum() to return the sum of x and 400 (providing the arguments in that order).
#
# 1. compute_sum(x, 400)
#
# ### Hierarchical function calls
#
# A function's statements may include function calls, known as hierarchical function calls or nested function calls. Code such as `user_input = int(input())` consists of such a hierarchical function call, in which the input() function is called and evaluates to a value that is then passed as an argument to the int() function.
#
# ### CHALLENGE ACTIVITY
#
# python-tutor-v5
#
# def calc_circle_area(circle_diameter):
#     pi_val = 3.14159265
#
#     circle_radius = circle_diameter / 2.0
#     circle_area = pi_val * circle_radius * circle_radius
#     return circle_area
#
# def calc_pizza_calories(pizza_diameter):
#     calories_per_square_inch = 16.7    # Regular crust pepperoni pizza
#
#     total_calories = calc_circle_area(pizza_diameter) * calories_per_square_inch
#     return total_calories
#
# print(f"12 inch pizza has {calc_pizza_calories(12.0):.2f} calories.")
# print(f"14 inch pizza has {calc_pizza_calories(14.0):.2f} calories.")
#
# calc_circle_area(circle_diameter)
#
# calc_circle_area
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f2
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f2
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f2
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f2
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# circle_radius
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f2
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# circle_radius
#
# circle_area
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f2
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# circle_radius
#
# circle_area
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# total_calories
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f1
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# total_calories
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f4
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f4
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f4
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f4
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# circle_radius
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f4
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# circle_radius
#
# circle_area
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_circle_area
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# calc_circle_area
#
# calc_circle_area_f4
#
# SPECIAL_FLOAT
#
# SPECIAL_FLOAT
#
# circle_diameter
#
# circle_radius
#
# circle_area
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# total_calories
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
#
# calc_pizza_calories
#
# calc_circle_area
#
# calc_pizza_calories
#
# calc_pizza_calories
#
# calc_pizza_calories_f3
#
# SPECIAL_FLOAT
#
# pizza_diameter
#
# calories_per_square_inch
#
# total_calories
#
# calc_circle_area(circle_diameter)
#
# calc_pizza_calories(pizza_diameter)
#
# 12 inch pizza has 1888.73 calories.
# 14 inch pizza has 2570.77 calories.
#
# calc_circle_area
#
# calc_pizza_calories
#
# ### PARTICIPATION ACTIVITY
#
# Type the expression for `placeholder_A` to calculate the total calories for a pizza with diameter `pizza_diameter`.
#
# 1. calc_pizza_calories(pizza_diameter)
#
# Type the expression for `placeholder_B` to calculate the calories per slice.
#
# 1. total_calories / calc_num_pizza_slices(pizza_diameter)
# 2. calc_pizza_calories(pizza_diameter) / calc_num_pizza_slices(pizza_diameter)
#
# ### CHALLENGE ACTIVITY
#
# Complete the function definition to  return the hours given minutes.
#
# Sample output with input: 210.0

# %%
3.5

# %% [markdown]
# ### CHALLENGE ACTIVITY
#
# def change_value(x):
#     return x + ${increment_value}
#
# print(change_value(${initial_value}))
#
# val_list = [ 1, 2, 3, 4]
#
# initial_value, increment_value = random.sample(val_list, 2)
# sum = initial_value + increment_value
#
# `change_value(${initial_value})` adds ${increment_value} to the function argument, ${initial_value}, and returns the sum, ${sum}.
#
# def change_values(x, y):
#     return x + y
#
# print(change_values(${initial_value1}, ${initial_value2}))
#
# val_list = [ 1, 2, 3, 4]
#
# initial_value1, initial_value2 = random.sample(val_list, 2)
# sum = initial_value1 + initial_value2
#
# `change_values(${initial_value1}, ${initial_value2})` takes two arguments, ${initial_value1} and ${initial_value2}, and returns their sum, ${sum}.
#
# def change_values(x, y):
#     result = x + y
#     return result
#
# print(change_values(${initial_value1}, ${initial_value2}))
#
# val_list = [ 1, 2, 3, 4]
#
# initial_value1, initial_value2 = random.sample(val_list, 2)
# sum = initial_value1 + initial_value2
#
# `change_values(${initial_value1}, ${initial_value2})` uses local variable result to calculate and store the sum of the arguments, ${initial_value1} and ${initial_value2}. The function then returns ${sum}, the value of result.

# %% [markdown]
# ### CHALLENGE ACTIVITY
#
# CodeWriting
#
# import random
# from common_functions import pick_from, pick_from_range
#
# def escape_underscores(s):
#     return s.replace(&apos;_&apos;, &apos;\_&apos;)
#
# def make_example(data):
#     template = &apos;:\n\n```\n{}\n```\n\n&apos; if &apos;\n&apos; in data[0] else &apos; `{}`, &apos;
#
#     return (&apos;Ex: If the input is&apos; + template + &apos;then the output is:\n\n```{}```&apos;).format(*data)
#
# function_names = [&apos;compute_val&apos;, &apos;compute_num&apos;, &apos;calc_val&apos;, &apos;calc_num&apos;, &apos;calculate_val&apos;, &apos;calculate_num&apos;, &apos;calculate_result&apos;, &apos;compute_result&apos;]
# input_vars = [&apos;num_in&apos;, &apos;num_input&apos;, &apos;input_num&apos;, &apos;in_num&apos;, &apos;input_value&apos;, &apos;input_val&apos;, &apos;value_in&apos;, &apos;num_read&apos;, &apos;value_read&apos;]
#
# def ${distractor.fn_name}(input_num):
#     ${distractor.solution_body}
#
# """ Your code goes here """
#
# ${distractor.input_name} = ${distractor.input_stmt}
#
# ${distractor.print_result}
#
# ${distractor.example_in}
#
# ${test.test2}
#
# ${test.test3}
#
# ${test.test4}
#
# ${test.test5}
#
# <p>Define a function ${distractor.fn_name}() that has one parameter and returns ${distractor.operation}.</p>
#
# ${distractor.prompt_examples}
#
# ${distractor.explanation}
#
# def make_test_permutation(meaningful_permutation, distractor_permutation):
#     qtype = meaningful_permutation[&apos;qtype&apos;]
#     K = distractor_permutation[&apos;K&apos;]
#     example_in2 = distractor_permutation[&apos;example_in2&apos;]
#     param_type = distractor_permutation[&apos;param_type&apos;]
#
#     test_case2 = example_in2
#     test_case3 = pick_from_range(-50, -5)
#     test_case4 = pick_from_range(13, 50)
#     test_case5 = pick_from_range(4, 12, exclude=[example_in2])
#
#     if qtype == &apos;condition&apos;:
#         test_case3 = pick_from_range(-10, K - 1)
#         test_case4 = K
#         test_case5 = pick_from_range(K + 1, 12)
#
#     if param_type == &apos;float&apos;:
#         test_case3 += pick_from_range(1, 9) / 10.
#         test_case5 += pick_from_range(1, 9) / 10.
#
#     return {
#         &apos;test2&apos;: test_case2,
#         &apos;test3&apos;: test_case3,
#         &apos;test4&apos;: test_case4,
#         &apos;test5&apos;: test_case5,
#     }
#
# def wrap_dropdown(ex):
#     # Only wrap with a dropdown if there are multiple examples
#     if ex.count(&apos;Ex&apos;) > 1:
#         return &apos;<details><summary><b>Click here for examples</b></summary>{}</details>&apos;.format(ex)
#     return ex
#
# operations = {
#     &apos;addition&apos;: [&apos;+&apos;, (lambda x, y: round(x + y, 2)), &apos;the parameter plus {}&apos;, &apos;is added&apos;, &apos;to&apos;, &apos;sum&apos;],
#     &apos;subtraction&apos;: [&apos;-&apos;, (lambda x, y: round(x - y, 2)), &apos;the parameter minus {}&apos;, &apos;is subtracted&apos;, &apos;from&apos;, &apos;difference&apos;],
#     &apos;multiplication&apos;: [&apos;*&apos;, (lambda x, y: round(x * y, 2)), &apos;{} times the parameter&apos;, &apos;is multiplied&apos;, &apos;by&apos;, &apos;product&apos;],
# }
#
# def make_distractor_permutation(meaningful_permutation):
#     qtype = meaningful_permutation[&apos;qtype&apos;]
#     param_type = pick_from([&apos;int&apos;, &apos;float&apos;])
#
#     fn_name = pick_from(function_names)
#     input_name = pick_from(input_vars)
#
#     symbol, arith_fn, template, verb, prep, result = pick_from(operations.values())
#
#     input_stmt = &apos;{}(input())&apos;.format(param_type)
#
#     example_in, example_in2, operand = random.sample(range(4, 10), 3)
#     param_type_word = &apos;integer&apos;
#     fn_call = &apos;{}({})&apos;.format(fn_name, input_name)
#     print_result = &apos;print({})&apos;.format(fn_call)
#     if param_type == &apos;float&apos;:
#         example_in, operand = random.sample([x / 10. for x in range(41, 90) if x % 10 != 0], 2)
#         param_type_word = &apos;floating-point&apos;
#         print_result = "print(f\"{%s:.2f}\")" % fn_call
#
#     example_out = round(arith_fn(example_in, operand), 2)
#
#     operation = template.format(operand)
#     solution_body = &apos;return input_num {} {}&apos;.format(symbol, operand)
#
#     explan_start = &apos;<p>The definition of {0}() begins with <code>def</code>&apos;.format(fn_name, param_type) \
#     + &apos;, followed by the function name {0} and a parameter\&apos;s name inside parentheses.</p>&apos;.format(fn_name)
#     explanation = &apos;\n\nEx: For input `{0}`, {1}({0}) is called. &apos;.format(example_in, fn_name)
#     explanation += &apos;{} {} {} &apos;.format(operand, verb, prep)
#     explanation += "the argument ({}). ".format(example_in)
#     explanation += &apos;Thus, <span style="white-space:nowrap">{} {} {} = {}</span> is returned.&apos;.format(example_in, symbol, operand, example_out)
#     explanations = [explan_start, explanation]
#
#     example_data = [[str(example_in), example_out]]
#     if param_type == &apos;float&apos;:
#         example_data[0][1] = &apos;{:.2f}&apos;.format(example_data[0][1])
#
#     K = 0
#     if qtype == &apos;condition&apos;:
#         chosen_operations = random.sample(operations.values(), 2)
#         symbol1, arith_fn1, template1, verb1, prep1, result1 = chosen_operations[0]
#         symbol2, arith_fn2, template2, verb2, prep2, result2 = chosen_operations[1]
#
#         operation1 = template1.format(operand)
#         operation2 = template2.format(operand)
#
#         K = pick_from_range(5, 10)
#         K_display = str(K)
#         conditions = [
#             [&apos;>&apos;, &apos;greater than&apos;, lambda x: x > K],
#             [&apos;>=&apos;, &apos;greater than or equal to&apos;, lambda x: x >= K],
#             [&apos;<&apos;, &apos;less than&apos;, lambda x: x < K],
#             [&apos;<=&apos;, &apos;less than or equal to&apos;, lambda x: x <= K],
#         ]
#
#         # Set in/out values that hit both branches
#         example_in1, example_in2 = pick_from_range(3, K - 1), pick_from_range(K + 1, 12)
#         exclude_conditions = []
#         if param_type == &apos;float&apos;:
#             K_display = &apos;{:.1f}&apos;.format(K)
#             example_in1 -= pick_from_range(1, 9) / 10.
#             example_in2 += pick_from_range(1, 9) / 10.
#             exclude_conditions = [conditions[1], conditions[3]]
#
#         condition_symbol, condition_words, condition_fn = pick_from(conditions, exclude=exclude_conditions)
#
#         if not condition_fn(example_in1):
#             example_in1, example_in2 = example_in2, example_in1
#
#         condition = &apos;{} {}&apos;.format(condition_words, K_display)
#         operation = &apos;{} if the parameter is {}. Otherwise, {}() returns {}&apos;.format(operation1, condition, fn_name, operation2)
#
#         solution_body = &apos;if input_num {} {}:\n&apos;.format(condition_symbol, K_display)
#         solution_body += &apos;        return input_num {} {}\n&apos;.format(symbol1, operand)
#         solution_body += &apos;    else:\n&apos;
#         solution_body += &apos;        return input_num {} {}&apos;.format(symbol2, operand)
#
#         example_data = [
#             [str(example_in1), round(arith_fn1(example_in1, operand), 2)],
#             [str(example_in2), round(arith_fn2(example_in2, operand), 2)],
#         ]
#         if param_type == &apos;float&apos;:
#             example_data[0][1] = &apos;{:.2f}&apos;.format(example_data[0][1])
#             example_data[1][1] = &apos;{:.2f}&apos;.format(example_data[1][1])
#         example_in, example_out = example_data[0]
#
#         expl_not1, expl_not2 = &apos;&apos;, &apos;not &apos;
#
#         expl_template = &apos;Ex: For input `{0}`, {1}({0}) is called. {0} is {2}{3}, so {4} {5} {6} &apos;
#         expl_template += &apos;the argument ({0}). Thus, <span style="white-space:nowrap">{0} {8} {4} = {9}</span> is returned.&apos;
#         expl_data = [
#             [example_in1, fn_name, expl_not1, condition, operand, verb1, prep1, result1, symbol1, example_data[0][1]],
#             [example_in2, fn_name, expl_not2, condition, operand, verb2, prep2, result2, symbol2, example_data[1][1]],
#         ]
#         explanations = [explan_start] + [expl_template.format(*data) for data in expl_data]
#
#     prompt_examples = map(make_example, example_data)
#
#     if len(prompt_examples) > 1:
#         prompt_examples[0] = prompt_examples[0].replace(&apos;Ex:&apos;, &apos;Ex 1:&apos;, 1)
#         prompt_examples[1] = prompt_examples[1].replace(&apos;Ex:&apos;, &apos;Ex 2:&apos;, 1)
#
#     return {
#         &apos;K&apos;: K,
#         &apos;fn_name&apos;: fn_name,
#         &apos;example_in&apos;: example_in,
#         &apos;example_in2&apos;: example_in2,
#         &apos;example_out&apos;: example_out,
#         &apos;explanation&apos;: &apos;\n\n&apos;.join(explanations),
#         &apos;input_name&apos;: input_name,
#         &apos;input_stmt&apos;: input_stmt,
#         &apos;operation&apos;: operation,
#         &apos;param_type&apos;: param_type,
#         &apos;param_type_word&apos;: param_type_word,
#         &apos;print_result&apos;: print_result,
#         &apos;prompt_examples&apos;: wrap_dropdown(&apos;\n\n&apos;.join(prompt_examples)),
#         &apos;solution_body&apos;: solution_body,
#     }
#
# def make_meaningful_permutation():
#     # Note: The condition permutation has been commented out on 10/10/24 by Amanda Bull
#     # due to a new markets book with the dependency: methods taught before branches.
#     # In case there is a decision to revert the CA back, we opted to leave the code in for now.
#
#     return {
#         # &apos;qtype&apos;: pick_from([&apos;calculation&apos;, &apos;condition&apos;]),
#         &apos;qtype&apos;: &apos;calculation&apos;,
#     }
#
# def ${distractor.fn_name}(input_num1, input_num2):
#     ${distractor.solution_body}
#
# """ Your code goes here """
#
# ${distractor.input_name}1 = ${distractor.input_stmt}
# ${distractor.input_name}2 = ${distractor.input_stmt}
#
# ${distractor.print_result}
#
# ${distractor.example_in}
#
# ${test.test2}
#
# ${test.test3}
#
# ${test.test4}
#
# Define a function ${distractor.fn_name}() that has two parameters and returns ${distractor.operation}.
#
# ${distractor.prompt_examples}
#
# ${distractor.explanation}
#
# def make_test_permutation(meaningful_permutation, distractor_permutation):
#     param_type = distractor_permutation[&apos;param_type&apos;]
#
#     test_case2 = [pick_from_range(6, 12)]
#     test_case2 += [pick_from_range(4, 12, exclude=test_case2)]
#     test_case3 = [pick_from_range(-50, -5), pick_from_range(4, 12, exclude=test_case2)]
#     test_case4 = [pick_from_range(4, 12, exclude=test_case2 + test_case3), pick_from_range(-20, -2, exclude=test_case3)]
#
#     if param_type == &apos;double&apos;:
#         test_case2[0] += pick_from_range(1, 9) / 10.
#         test_case2[1] += pick_from_range(1, 9) / 10.
#         test_case3[0] += pick_from_range(1, 9) / 10.
#         test_case3[1] += pick_from_range(1, 9) / 10.
#         test_case4[0] += pick_from_range(1, 9) / 10.
#         test_case4[1] += pick_from_range(1, 9) / 10.
#
#     return {
#         &apos;test2&apos;: &apos;{}\n{}&apos;.format(*test_case2),
#         &apos;test3&apos;: &apos;{}\n{}&apos;.format(*test_case3),
#         &apos;test4&apos;: &apos;{}\n{}&apos;.format(*test_case4),
#     }
#
# calculations = [
#     [&apos;the product of the two parameters plus {}&apos;, &apos;({0} * {1}) + {2}&apos;, (lambda x, y, z: (x * y) + z), (lambda x, y, z: x * y), &apos;the product of the two arguments, so <span style="white-space:nowrap">{0} * {1} = {3}</span>&apos;, &apos;adds {2} to the product and returns the sum, so <span style="white-space:nowrap">{3} + {2} = {4}</span>&apos;],
#     [&apos;the product of the two parameters minus {}&apos;, &apos;({0} * {1}) - {2}&apos;, (lambda x, y, z: (x * y) - z), (lambda x, y, z: x * y), &apos;the product of the two arguments, so <span style="white-space:nowrap">{0} * {1} = {3}</span>&apos;, &apos;subtracts {2} from the product and returns the difference, so <span style="white-space:nowrap">{3} - {2} = {4}</span>&apos;],
#     [&apos;the sum of the two parameters times {}&apos;, &apos;({0} + {1}) * {2}&apos;, (lambda x, y, z: (x + y) * z), (lambda x, y, z: x + y), &apos;the sum of the two arguments, so <span style="white-space:nowrap">{0} + {1} = {3}</span>&apos;, &apos;multiplies {2} by the sum and returns the product, so <span style="white-space:nowrap">{3} * {2} = {4}</span>&apos;],
#     [&apos;the sum of the two parameters minus {}&apos;, &apos;{0} + {1} - {2}&apos;, (lambda x, y, z: x + y - z), (lambda x, y, z: x + y), &apos;the sum of the two arguments, so <span style="white-space:nowrap">{0} + {1} = {3}</span>&apos;, &apos;subtracts {2} from the sum and returns the difference, so <span style="white-space:nowrap">{3} - {2} = {4}</span>&apos;],
#     [&apos;the result of subtracting the second parameter from the product of 2 and the first parameter&apos;, &apos;(2 * {0}) - {1}&apos;, (lambda x, y, z: (2 * x) - y), (lambda x, y, z: 2 * x), &apos;the product of 2 and the first argument ({0}), so <span style="white-space:nowrap">2 * {0} = {3}</span>&apos;, &apos;subtracts the second argument ({1}) from the product, and returns the difference, so <span style="white-space:nowrap">{3} - {1} = {4}</span>&apos;],
#     [&apos;the result of subtracting the product of 2 and the second parameter from the first parameter&apos;, &apos;{0} - (2 * {1})&apos;, (lambda x, y, z: x - (2 * y)), (lambda x, y, z: 2 * y), &apos;the product of 2 and the second argument ({1}), so <span style="white-space:nowrap">2 * {1} = {3}</span>&apos;, &apos;subtracts the product from the first argument ({0}) and returns the difference, so <span style="white-space:nowrap">{0} - {3} = {4}</span>&apos;],
#     [&apos;the result of adding the first parameter to the product of {} and the second parameter&apos;, &apos;{0} + ({2} * {1})&apos;, (lambda x, y, z: x + (z * y)), (lambda x, y, z: z * y), &apos;the product of {2} and the second argument ({1}), so <span style="white-space:nowrap">{2} * {1} = {3}</span>&apos;, &apos;adds the product to the first argument ({0}) and returns the sum, so <span style="white-space:nowrap">{0} + {3} = {4}</span>&apos;],
#     [&apos;the result of subtracting the product of {} and the second parameter from the first parameter&apos;, &apos;{0} - ({2} * {1})&apos;, (lambda x, y, z: x - (z * y)), (lambda x, y, z: z * y), &apos;the product of {2} and the second argument ({1}), so <span style="white-space:nowrap">{2} * {1} = {3}</span>&apos;, &apos;subtracts the product from the first argument ({0}) and returns the difference, so <span style="white-space:nowrap">{0} - {3} = {4}</span>&apos;],
# ]
#
# def make_distractor_permutation(meaningful_permutation):
#     param_type = meaningful_permutation[&apos;qtype&apos;]
#
#     fn_name = pick_from(function_names)
#     input_name = pick_from(input_vars)
#
#     template, code_template, arith_fn, intermediate_fn, computes, verb_predicate = pick_from(calculations)
#
#     ex_in1, ex_in2 = pick_from_range(2, 5), pick_from_range(6, 9)
#     operand = pick_from_range(2, 10, exclude=[ex_in1, ex_in2])
#
#     input_stmt = &apos;{}(input())&apos;.format(param_type)
#
#     fn_call = &apos;{0}({1}1, {1}2)&apos;.format(fn_name, input_name)
#     param_type_word = &apos;integer&apos;
#     print_result = &apos;print({})&apos;.format(fn_call)
#     if param_type == &apos;float&apos;:
#         ex_in1, ex_in2, operand = random.sample([x / 10. for x in range(41, 90) if x % 10 != 0], 3)
#         param_type_word = &apos;floating-point&apos;
#         print_result = "print(f\"{%s:.2f}\")" % fn_call
#
#     example_in = &apos;{}\n{}&apos;.format(ex_in1, ex_in2)
#     example_out = round(arith_fn(ex_in1, ex_in2, operand), 2)
#
#     example_data = [[example_in, example_out]]
#     if param_type == &apos;float&apos;:
#         example_data[0][1] = &apos;{:.2f}&apos;.format(example_data[0][1])
#
#     operation = template.format(operand)
#     code = code_template.format(&apos;input_num1&apos;, &apos;input_num2&apos;, operand)
#     solution_body = &apos;return {}&apos;.format(code);
#
#     intermediate_val = round(intermediate_fn(ex_in1, ex_in2, operand), 2)
#     computes = computes.format(ex_in1, ex_in2, operand, intermediate_val)
#     verb_predicate = verb_predicate.format(ex_in1, ex_in2, operand, intermediate_val, example_out)
#     expl = &apos;<p>The definition of {0}() begins with <code>def</code>&apos;.format(fn_name, param_type) \
#     + &apos;, followed by the function name {0} and the two parameters\&apos;s names &apos;.format(fn_name)
#     expl += &apos;separated by commas inside parentheses.</p>&apos;
#
#     explanation = expl + &apos;\n\nEx: For input\n\n```\n{}\n```\n\n&apos;.format(example_in)
#     explanation += &apos;{0}() first computes {1}. Then, {0}() {2}.&apos;.format(escape_underscores(fn_name), computes, verb_predicate)
#
#     prompt_examples = map(make_example, example_data)
#
#     return {
#         &apos;example_in&apos;: example_in,
#         &apos;example_out&apos;: example_out,
#         &apos;explanation&apos;: explanation,
#         &apos;fn_name&apos;: fn_name,
#         &apos;input_name&apos;: input_name,
#         &apos;input_stmt&apos;: input_stmt,
#         &apos;operation&apos;: operation,
#         &apos;param_type&apos;: param_type,
#         &apos;param_type_word&apos;: param_type_word,
#         &apos;print_result&apos;: print_result,
#         &apos;prompt_examples&apos;: &apos;\n\n&apos;.join(prompt_examples),
#         &apos;solution_body&apos;: solution_body,
#     }
#
# def make_meaningful_permutation():
#     return {
#         &apos;qtype&apos;: pick_from([&apos;int&apos;, &apos;float&apos;]),
#     }
#
# ---
# _API Debug: 31 resources fetched. Types: html(13), custom(10), multiple_choice(2), short_answer(5), container(1)_
