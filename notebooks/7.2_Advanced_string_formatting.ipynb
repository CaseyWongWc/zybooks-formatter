# %% [markdown]
# ## 7.2 Advanced string formatting
#
# ### Field width
#
# A program must display formatted output beyond the ability of basic print usage such as `print(x)`. Consider a program that displays a table of soccer player statistics:
#
# > **A formatted table of soccer statistics.**
# >

# %%
> Player Name      Goals    Games Played     Goals Per Game   
> ------------------------------------------------------------
> Sadio Mane         22          36               0.61        
> Mohamed Salah      22          38               0.58        
> Sergio Aguero      21          33               0.64        
> Jamie Vardy        18          34               0.53        
> Gabriel Jesus       7          29               0.24
>

# %% [markdown]
# Note in the above example how the text is formatted into columns with the contents of each column (except the leftmost column) centered under the column header. A programmer could achieve this careful formatting by placing spaces into their output strings, but each row would require different numbers of spaces depending on the player name (longer names require fewer spaces between the first and second columns).
#
# A format specification may include a field width that defines the minimum number of characters that must be inserted into the string. If the replacement value is smaller in size than the given field width, then the string is padded with space characters. Field widths set on each column in the example above cause the output to be formatted.
#  A field width is defined in a format specification by including an integer after the colon, as in `{name:16}` to specify a width of 16 characters. Numbers will be right-aligned within the width by default, whereas most other types like strings will be left-aligned.
#
# ### PARTICIPATION ACTIVITY: Field width.
#
# Static Figure:
# Begin python code:
# print(f"{'Player Name':16}{'Goals':8}")
# print("-" * 24)
# print(f"{'Sadio Mane':16}{'22':8}")
# print(f"{'Gabriel Jesus':16}{'7':8}")
# End python code.
#
# Each character of each print statement is shown on a table. Each print statement occupies a row in the table, with there being 4 total rows. Each column of the table is labeled with an index starting from 0 and ending with 23. Indexes 0 to 15 are grouped together, and indexes 16 to 23 are also grouped together.
#
# 01234567891011121314151617181920212223
# Player Name     Goals
# ------------------------
# Sadio Mane      22
# Gabriel Jesus   7
#
# Below the table is an output console containing the print statement outputs. The output console contains:
# Player Name     Goals
# ------------------------
# Sadio Mane      22
# Gabriel Jesus   7
#
# Step 1: "Player Name" is inserted into the leftmost part of the first 16-character wide field. "Goals" is inserted into the leftmost part of the second 8-character wide field. The lines of code "print(f"{'Player Name':16}{'Goals':8}")" and "print("-" * 24)" are highlighted, and the contents of the print statements are shown in the table. Each of the print statements contents from the table are then displayed on the output console below, printing in groups based on the print statements. "Player Name     " is printed (index 0 to 15), and on the same line, "Goals   " is printed afterwards (index 16 to 23). The next row of the table is then printed (index 0 to 23). The output console starts empty, and eventually shows:
# Player Name     Goals
# ------------------------
#
# Step 2: The inserted values align themselves automatically according to the field width. Note: The numbers output here are strings (Ex: "22") and are left-aligned. Numerical types, like integers, would be right-aligned within the width by default. The lines of code, "print(f"{'Sadio Mane':16}{'22':8}")" and "print(f"{'Gabriel Jesus':16}{'7':8}")" are highlighted, and the contents of the print statements are shown in the table. Each of the print statements contents from the table are then displayed on the output console below, printing in groups based on the print statements. "Sadio Mane      " is printed (index 0 to 15), and on the same line, "22      " is printed afterwards (index 16 to 23).  "Gabriel Jesus   " is printed on a new line (index 0 to 15), and on the same line, "7       " is printed afterwards (index 16 to 23). Finally, the output console shows:
# Player Name     Goals
# ------------------------
# Sadio Mane      22
# Gabriel Jesus   7
#
# ### PARTICIPATION ACTIVITY: Format specification field widths.
#
# {name:
#
# **1.** Complete the format specification to assign a field width of 10 characters. }
# Answer: 10
# *Hint: The field width is assigned by providing an integer that follows the colon in the replacement field.*
# *A field width of 10 will ensure that at least 10 characters are inserted into the string.*
#
# **2.** Write a complete replacement field that assigns a field with named value "count" and a field width of 5.
# Answer: {count:5}
# *Hint: {count:?}*
# *"count" is the name of the value to insert into the f-string. The field width of 5 ensures at least 5 characters are inserted into the string.*
#
# ### CHALLENGE ACTIVITY: Field widths.
#
# **Level 1:**
#
# What is the output?

# %%
name = "[name]"
print(f"{name:6}")

# %% [markdown]
# *The output includes at least 6 characters. If the name is less than 6 characters then empty spaces are added after the name.
#
# "[name]" has [name length] characters. So, no spaces are added after "[name]".*
#
# **Level 2:**
#
# What is the output?

# %%
name = "[name]"
points = 10
print(f"{name:6}{points:4}")

# %% [markdown]
# *"[name]" has 3 characters, and the field width is 6. Since strings are left-aligned, [name diff] extra spaces are added after "[name]".
# "10" has 1 characters, and the field width is 4. Since numbers are right-aligned, [point diff] extra spaces are added before "10".
#
# So, [total spaces] spaces exist between "[name]" and "10".*
#
# **Level 3:**
#
# What is the output?

# %%
name = "[name]"
matches = 20
points = 7
print(f"{name:6}{points:3}{matches:4}")

# %% [markdown]
# *"[name]" has 3 characters, and the field width is 6. Since strings are left-aligned, [name diff] extra spaces are added after "[name]".
# "7" has 1 character, and the field width is 3. "20" has 2 characters, and the field width is 4. Since numbers are right-aligned, [point diff] extra spaces are added before "7", and 2 extra spaces are added before "20".
#
# So, [total spaces] spaces exist between "[name]" and "7", and 2 spaces exist between "7" and "20".*
#
# ### Aligning text
#
# A format specification can include an alignment character that determines how a value should be aligned within the width of the field. Alignment is set in a format specification by adding a special character before the field width integer. The basic set of possible alignment options include left-aligned () and centered (^). Numbers will be right-aligned within the width by default, whereas most other types like strings will be left-aligned.
#
# > **Aligning strings within a field.**
# > Consider the following code that prints a table, and how changing the alignment impacts the column organization.
# >

# %%
> names = ["Sadio Mane", "Gabriel Jesus"]
> goals = [22, 7]
> 
> print()        #Replaced in table below
> print("-" * 24)
> for i in range(2):
>     print()    #Replaced in table below
>

# %% [markdown]
# > Alignment type
# >
# > Output
# >
# > Left-aligned
# > `f"{'Player Name':<16}{'Goals':<8}"``f"{names[i]:<16}{goals[i]:<8}"`
# >

# %%
> Player Name     Goals   
> ------------------------
> Sadio Mane      22      
> Gabriel Jesus   7
>

# %% [markdown]
# > Right-aligned
# > `f"{'Player Name':>16}{'Goals':>8}"``f"{names[i]:>16}{goals[i]:>8}"`
# >

# %%
> Player Name   Goals
> ------------------------
>       Sadio Mane      22
>    Gabriel Jesus       7
>

# %% [markdown]
# > Centered
# > `f"{'Player Name':^16}{'Goals':^8}"``f"{names[i]:^16}{goals[i]:^8}"`
# >

# %%
> Player Name    Goals  
> ------------------------
>    Sadio Mane      22   
>  Gabriel Jesus     7
>

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Aligning text in fields.
#
# **1.**

# %%
f"{'Bob':<5}"

# %% [markdown]
# Answer: `Bob  `
# *Hint: The minimum field width is 5, so there may be extra spaces inserted after "Bob". "<" assigns left-alignment.*
# *"<" indicates that the inserted string should be left-aligned within the field. Left-aligned is the default for string values.*
#
# **2.**

# %%
f"{'Bob':>5}"

# %% [markdown]
# Answer: `  Bob`
# *Hint: The minimum field width is 5, so there may be extra spaces inserted before "Bob". ">" assigns right-alignment.*
# *">" indicates that the inserted string should be right-aligned within the field.*
#
# **3.**

# %%
f"{'Bob':^5}"

# %% [markdown]
# Answer: ` Bob `
# *Hint: The minimum field width is 5, so there may be extra spaces around before "Bob". "^" centers the value in the field.*
# *"^" indicates that the inserted string should be centered within the field.*
#
# **4.**

# %%
f"{'Bob':<5}{1:<2}"

# %% [markdown]
# Answer: `Bob  1 `
# *Hint: Both fields are left-aligned. Be sure to account for the minimum field width values.*
# *"Bob" is left-aligned in its field, and two extra spaces are added after to meet the minimum field width requirement. "1" is also left-aligned, and one extra space is added.*
#
# **5.**

# %%
f"{'Bob':<5}{1:>2}"

# %% [markdown]
# Answer: Bob   1
# *Hint: "Bob" is left-aligned, but "1" is right-aligned. Be sure to account for the minimum field width values.*
# *"Bob" is left-aligned in its field, and two extra spaces are added after to meet the minimum field width requirement. "1" is right-aligned, and one extra space is added before the value.*
#
# ### Fill
#
# The fill character is used to pad a replacement field when the inserted string is smaller than the field width. The default fill character is an empty space `" "`. A programmer may define a different fill character in a format specification by placing the different fill character before the alignment character. Ex: `{score:0>4}`  generates "0009" if score is 9 or "0250" if score is 250.
#
# > **Using fill characters to pad tables.**
# > Format specification
# > Value of score
# > Output
# >
# > `{score:}`
# > 9
# >

# %%
> 9
>

# %% [markdown]
# > `{score:4}`
# > 9
# >

# %%
> 9
>

# %% [markdown]
# > `{score:0>4}`
# > 9
# >

# %%
> 0009
>

# %% [markdown]
# > `{score:0>4}`
# > 18
# >

# %%
> 0018
>

# %% [markdown]
# > `{score:0^4}`
# > 18
# >

# %%
> 0180
>

# %% [markdown]
# A programmer can set different alignments, widths, and fills on each field to construct neatly formatted output, as demonstrated below.
#
# **PythonTutor: Fill characters in strings.**
#
# Shows the trace of a program that prints the final score of a sports game, using 0 as a fill character.

# %%
name = "Wayne Rooney"
goals = 36

# Use default empty space fill character
print(f"{name:<16}{goals:>6}")

# Use "0" as a fill character for score
print(f"{name:<16}{goals:0>6}")

# Use "_" as fill character for name
print(f"{name:_<16}{goals:0>6}")

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Fill characters.
#
# **1.** What's the fill character in the following format specification?
#
# `{score:*>4}`
#
# **2.** What's the fill character in the following format specification?
#
# `{score:>4}`
#
# **3.** If `name = "Sally"`, what is the result of: `{name:@>8}`?
#
# ### Floating-point precision
#
# A programmer  sets the number of digits to the right of a floating-point number to print. The optional precision component of a format specification indicates how many digits should be included in the output of floating types. The precision follows the field width component in the format specification, if a width is specified at all, and starts with a period character. Ex: ` f"{1.725:.1f}"` indicates a precision of 1, thus the resulting string would be "1.7".
#
# If the specified precision is greater than the number of digits available, trailing 0s are appended. Ex: `f"{1.5:.3f}"` results in the string "1.500". If the specified precision is less than the existing precision in the given number, then the number is rounded. Ex: `f"{1.666:.2f}"` results in the string "1.67".
#
# > **String formatting example: Setting precision of floating-point values.**
# >

# %%
> import math
> real_pi = math.pi  # math library provides close approximation of pi
> approximate_pi = 22.0 / 7.0  # Approximately correct pi to within 2 decimal places
> 
> print(f"pi is {real_pi}")
> print(f"22/7 is {approximate_pi}")
> print(f"22/7 looks better like {approximate_pi:.2f}")
>

# %% [markdown]
# >

# %%
> pi is 3.141592653589793
> 22/7 is 3.142857142857143
> 22/7 looks better like 3.14
>

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Floating-point precision in formatted strings.
#
# **1.**

# %%
f"{5:.1f}"

# %% [markdown]
# Answer: 0
# *Hint: The number to the left of the decimal is given and `.1f` indicates a precision of 1 to the right of the decimal.*
# *The format specification specifies 1 precision, which for a float means adding a 0 to the right of the decimal to generate the string "5.0".*
#
# **2.**

# %%
f"{5:.3f}"

# %% [markdown]
# Answer: 000
# *Hint: The number to the left of the decimal is given and `.3f` indicates a precision of 3 to the right of the decimal.*
# *The format specification specifies 3 precision, which for a float means adding three 0s to the right of the decimal to generate the string "5.000".*
#
# **3.**

# %%
f"{5.25:.3f}"

# %% [markdown]
# Answer: 5.250
# *Hint: `.3f` indicates a precision of 3 to the right of the decimal.*
# *The format specification specifies 3 precision. Since x already has two numbers to the right of the decimal, one must be added to reach the correct amount of precision.*
#
# **4.**

# %%
f"{5.2589:.3f}"

# %% [markdown]
# Answer: 5.259
# *Hint: `.3f` indicates a precision of 3 to the right of the decimal. Since 5.2589 has a precision greater than 3, the last digit will be rounded up to fit within decimal places.*
# *Since the precision `.3f` is less than the existing precision of x, the last decimal place of the number is rounded up, resulting in the string "5.259".*
#
# **5.**

# %%
f"{5:4.1f}"

# %% [markdown]
# Answer: ` 5.0`
# *Hint: The minimum field width in the format specification is 4. Leading spaces will be prepended to the string to meet the minimum field width if necessary.*
# *The value of x is converted to `5.0` by the precision specification. The three characters of `5.0` require adding a single leading space to meet the minimum field width.*
#
# ### CHALLENGE ACTIVITY: Advanced string formatting. (3 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# [...]
#
# **Explanation pattern:**
# print(f" ") is used to output formatted strings. The field width integer is [...]. In a format specification, an alignment character can be added before the field width integer. A fill character can be added before the alignment character. [...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# Floating-point number [...] is read from input.[...] Use one print(f" ") statement to output [...].
#
# **Explanation pattern:**
# print(f" ") is used to output formatted strings. `.[...]f` specifies [...] precision and formats [...]. If the specified precision is greater than the number of digits available, trailing 0s are appended.
#
# **Code structure:**

# %%
___ = float(input())___
""" Your code goes here """

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# Three strings are read from input and stored into list [...]. Then, three more strings are read from input and stored into list [...]. Lastly, string separator_char is read from input. Use four print(f" ") statements and one print() statement to output the following five lines: "[...]", with a field width of [...], centered[...]. Then "[...]", with a field width of [...], centered.
# [...] instances of separator_char.
# [...][0], with a field width of [...], [...]. Then, [...][0] with a field width of [...], [...].
# [...][1], with a field width of [...], [...]. Then, [...][1] with a field width of [...], [...].
# [...][2], with a field width of [...], [...]. Then, [...][2] with a field width of [...], [...].
#
# **Explanation pattern:**
# print(f" ") is used to output formatted strings. {'[...]':^[...]} and {'[...]':^[...]} centers "[...]" and "[...]", respectively, with a field width of [...].
# separator_char * [...] creates a string with [...] instances of separator_char.[...]
#
# **Code structure:**

# %%
___ = input().split()
___ = input().split()
separator_char = input()
""" Your code goes here """

# %% [markdown]
# ---
# _API Debug: 22 resources fetched. Types: html(10), container(4), custom(4), short_answer(3), multiple_choice(1)_
