# %% [markdown]
# ## 1.3 Basic input and output

# %% [markdown]
# ### Basic text output
#
# Text is output from a Python program using the built-in function print( ).  Ex: `print("hello world!")`. Text enclosed in quotes is known as a string. Text in strings may have letters, numbers, spaces, or symbols like @ or #. Ex: "hello123@zybooks.com", "Welcome!", and "2005" are strings.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Executing a simple Python program.
#
# Static figure: A block of Python code and an output box.
#
# Begin Python code.
# print("Hello there.")
# print("My name is...")
# print("Carl?")
# End Python code.
#
# Output is:
# Hello there.
# My name is...
# Carl?
#
# Step 1: A program runs line by line, starting from the top.  The first line prints "Hello there."
# Step 2: Each print statement puts their output on a new line.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Basic text output.
#
# **1.** *Hello*
# Answer: print('Hello') or print ('Hello') or print("Hello") or print ("Hello")
# *Hint: Use the `print()` function. Don't forget parentheses, matching quotes, and correct capitalization.*
# **Hello* is printed by the program. Any output that follows would print on the next line.*
#
# **2.** *Email sent!*
# Answer: print('Email sent!') or print ('Email sent!') or print("Email sent!") or print ("Email sent!")
# *Hint: Use the `print()` function. Don't forget parentheses, matching quotes, and correct capitalization.*
# **Email sent!* is printed by the program. Any output that follows would print on the next line. A string can contain numbers, letters, or special characters.*
#
# **3.** *bill.gates99@msft.com*
# Answer: print('bill.gates99@msft.com') or print ('bill.gates99@msft.com') or print("bill.gates99@msft.com") or print ("bill.gates99@msft.com")
# *Hint: Use the `print()` function. Don't forget parentheses, matching quotes, and correct capitalization.*
# **bill.gates99@msft.com* is printed by the program. Any output that follows would print on the next line. A string can contain numbers, letters, or special characters.*

# %% [markdown]
# ### Print and the newline character
#
# Output can be moved to the next line using the newline character "\n". Ex: `print("1\n2\n3")` prints "1" on the first line, "2" on the second line, and "3" on the third line of output. An output newline is the equivalent of pressing the Enter key on a keyboard to get to the next line.
#
# `print()` always outputs an invisible newline character at the end of the statement.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Printing newlines.
#
# Static figure: a block of code with the contents:
#
# Begin Python code.
# print("Hello\nthere.")
# print()
# print("Nice to")
# print("meet you.")
# End Python code.
#
# An output box is below and contains the following:
# Hello
# there.
#
# Nice to
# meet you.
#
# Step 1: The newline character \n will move output to the next line. Use \n to place a line break in a string.
# Step 2: The print() function automatically outputs a newline character after printing the string.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Basic text output.
#
# **1.** Welcome!
# - `print(Welcome!)`
# - `print('Welcome!")`
# - `print("Welcome!")` ✓
# - N/A
# *The string *Welcome!* is printed. Then, a newline is printed, meaning any subsequent output would appear on the next line. A string can contain numbers, letters, and special characters.*
#
# **2.** Password is: BaNaNa123
# - `print("Welcome!")`
# - `print "Password is: BaNaNa123"`
# - `print("Password is: BaNaNa123")` ✓
# - N/A
# *The string *Password is: BaNaNa123* is printed. Then, a newline is printed. A string can contain numbers, letters, and special characters.*
#
# **3.** Pikachu is the superior warrior
# - `print(Pikachu is the superior warrior")`
# - `("Pikachu is the superior warrior")`
# - `print()"Pikachu is the superior warrior"`
# - N/A ✓
# *A valid option should have matching quotes, use the `print()` function, and include the desired string.*
#
# **4.** Youdidit!
# - `Print("You/ndid/nit!")`
# - `print("\n You \n did \n it! \n")`
# - `print("You\ndid\nit!")` ✓
# - N/A
# *The newline character, \n, causes each word to print on a newline. The newline character is the equivalent of pressing "Enter" or "Return" when producing output.*

# %% [markdown]
# ### CHALLENGE ACTIVITY: Output an eight with asterisks.
#
# Drag and drop the code statements to output the following figure with asterisks.

# %%
*****
*   *
*****
*   *
*****

# %% [markdown]
# **Solution:**

# %%
print("*****")
print("*   *")
print("*****")
print("*   *")
print("*****")

# %% [markdown]
# ### Output variables and multiple values
#
# The value of a variable can be printed out via: `print(variable_name)`  (without quotes around the variable name). A single output line may include multiple strings and variables separated by commas. A space character is automatically added between each.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Printing variables and multiple values.
#
# Static figure: a block of code containing:
#
# wage = 400
# print("Your daily wage is $", wage)
# weekly_wage = 2000
# print("$", wage, "per day is $", weekly_wage, "per week")
#
# and the output of the code:
#
# Your daily wage is $ 400
# $ 400 per day is $ 2000 per week

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Basic variable output.

# %% [markdown]
# **1.**

# %%
num_wheels = 4
print(num_wheels)

# %% [markdown]
# - 4 ✓
# - num_wheels
# - num_wheels = 4
# *The value of num_wheels is output: *4**

# %% [markdown]
# **2.**

# %%
num_wheels = 4
print("Number of wheels:", num_wheels)

# %% [markdown]
# - 4
# - Number of wheels
# - Number of wheels: 4 ✓
# - Number of wheels:4
# *The first string *Number of wheels:* is printed, and then a space, and then the value of num_wheels: *4*.*

# %% [markdown]
# **3.**

# %%
num_wheels = 4
vehicle_type = "pickup truck"
print("A", vehicle_type, "has", num_wheels, "wheels")

# %% [markdown]
# - Apickuptruckhas4wheels
# - A vehicle_type has num_wheels wheels
# - A pickup truck has 4 wheels ✓
# *Each value is printed from left to right, with spaces in between each value and variable values substituted in place of the names.*

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Basic variable output.
#
# **1.** *Number of apples: 3*
# Answer: print('Number of apples:', num_apples) or print("Number of apples:", num_apples) or print('Number of apples:',num_apples) or print("Number of apples:",num_apples)
# *Hint: print should have 2 values inside the parentheses: "Number of apples:" and num_apples.*
# *The *Number of apples:* string is printed first, then a space, then the value of the variable num_apples.*
#
# **2.** *I have 2 types of fruit*
# Answer: print('I have', num_fruit_types, 'types of fruit') or print("I have", num_fruit_types, "types of fruit") or print('I have', num_fruit_types, "types of fruit") or print("I have", num_fruit_types, 'types of fruit') or print('I have',num_fruit_types,'types of fruit') or print("I have",num_fruit_types,"types of fruit")
# *Hint: print should have 3 values inside the parentheses: "I have", num_fruit_types, and "types of fruit".*
# *Each value in the print is output from left to right: the string *I have*, followed by a space, then the value of the num_fruit_types variable, another space, then the string *types of fruit*.*
#
# **3.** *3 apples and 5 bananas*
# Answer: print(num_apples, 'apples and', num_bananas, 'bananas') or print(num_apples, "apples and", num_bananas, "bananas") or print(num_apples, 'apples and', num_bananas, "bananas") or print(num_apples, "apples and", num_bananas, "bananas") or print(num_apples,'apples and',num_bananas,'bananas') or print(num_apples,"apples and",num_bananas,"bananas")
# *Hint: print should have 4 values inside the parentheses: two strings and two variables.*
# *Each value in the print is output from left to right with spaces in between them: the variable num_apples, the string *apples and*, the variable num_bananas, and finally the string *bananas*.*
#
# **4.** *I have:
#  3 apples*
# Answer: print('I have:\n', num_apples, 'apples') or print("I have:\n", num_apples, "apples") or print('I have:\n', num_apples, "apples") or print("I have:\n", num_apples, 'apples') or print('I have:\n',num_apples,'apples') or print("I have:\n", num_apples, "apples")
# *Hint: print should have 3 values inside the parentheses: "I have:\n", num_apples, and "apples".*
# *Each value in the print is output from left to right: the string *I have:*, followed by a newline, then the value of the num_apples variable, another space, then the string *apples*.*

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Single print statement.
#
# **1.** `print("You are", age, "years old.")`
# Answer: You are 22 years old.
# *Hint: Starts with: You are 22*
# *Consecutive items are separated by spaces in the output. After the three items are output, a newline is printed by default.*
#
# **2.** `print(pet_name, "the", pet, "is", age)`
# Answer: Gerald the dog is 22
# *Hint: ? the ? is ?*
# *Each comma separated item is printed with a space between each item. After the five items are output, a newline is printed by default.*

# %% [markdown]
# ### Keeping output on the same line
#
# Each use of `print()` outputs on a new line. However, sometimes a programmer may want to keep output on the same line. Adding `end=" "` inside of `print()` keeps the output of the next print on the same line, separated by a single space character. Ex: `print("Hello", end=" ")`. Any character, or multiple characters, can be used instead of a space character.

# %% [markdown]
# > **Printing text on the same row.**
# >

# %%
> # Including end=" " keeps output on same line
> print("Hello there.", end=" ")
> print("My name is...", end=" ")
> print("Carl?")
>

# %% [markdown]
# >

# %%
> Hello there. My name is... Carl?
>

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Printing text on the same row.
#
# Which pair of statements prints the output *Halt! No access!* on the same line?
# - print("Halt!")
# print("No access!")
# - print("Halt!", end=" ")
# print("No access!") ✓
# - print(Halt!, end=" ")
# print(No Access!, end=" ")
# *The addition of `end=" "` allows the output to be printed on the same line with a space after "Halt!".*

# %% [markdown]
# ### Moving output to the next line
#
# An escape sequence is a string that has a special meaning, like the newline character "\n", that always starts with a backslash "\". Other escape sequences exist, such as "\t" to insert a tab, or "\\" to print an actual backslash character.
#
# Any space, tab, or newline is called whitespace.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Newline characters and escape sequences.
#
# Static figure: a code block with the contents:
#
# print("Name\tJob\n------------------")
# print("Ann\tDeveloper\nJoe\tInfluencer")
#
# and the formatted output of the code:
#
# Name            Job

# %% [markdown]
# ------------------

# %% [markdown]
# Ann            Developer
# Joe            Influencer
#
# NOTE: In a normal programming environment, program input is typed in as the program runs and completed by pressing the enter key. Pressing the enter key will insert a newline. Since zyBooks input is pre-entered, the enter key press cannot be inferred. Thus, activities that require pre-entered input may need extra newline characters or blank print statements in zyBooks compared to other environments.

# %% [markdown]
# ### CHALLENGE ACTIVITY: Enter the output.

# %% [markdown]
# **Level 1:**
#
# What is the output?

# %%
# print() adds a newline after the output
print("Ann is good.")

# %% [markdown]
# *First, the string `Ann is good.` is output. Then, `print()` automatically adds a newline, just like pressing the **Enter** (or **Return**) key after the string.*

# %% [markdown]
# **Level 2:**
#
# What is the output?

# %%
print("Ann")
print("is")
print("good.")

# %% [markdown]
# *Each `print()` adds a newline at the end, just like pressing the **Enter** (or **Return**) key. The first `print()` outputs `Ann`, followed by a newline. The second `print()` outputs `is`, followed by a newline. The third `print()` outputs `good.`, followed by a newline.*

# %% [markdown]
# **Level 3:**
#
# What is the output?

# %%
person_age = 18

# Each item in the output will be separated by a space
print("Ann is:", person_age)

# %% [markdown]
# *Multiple items can be output in the same line using a single `print()`. Each item will be separated by a space in the output.- First, `Ann is:` is output, followed by a space.- Then, the value of **person_age** is output, followed by a newline.*

# %% [markdown]
# **Level 4:**
#
# What is the output?

# %%
person_age = 18
print("Ann is", person_age, "years old.")

# %% [markdown]
# *A variable can be output between two string literals using a single `print()`. Each item will be separated by a space in the output.- First, `Ann is` is output, followed by a space.- Then, the value of **person_age** is output, followed by a space.- Lastly, `years old.` is output, followed by a newline.*

# %% [markdown]
# ### Basic input
#
# Many useful programs allow a user to enter values, such as typing a number, a name, etc.
#
# The input() function is used to read input from a user. The statement `best_friend = input()` will read text entered by the user, and assign the result as a new string to the best_friend variable. The input() function causes the program to wait until the user has entered text and pushed the return key.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: A program can get an input value from the keyboard.
#
# Static Figure: A block of Python code, variables table, input box, and an output box
#
# Begin Python code:
# print("Enter name of best friend:", end=" ")
# best_friend = input()
# print("My best friend is", best_friend)
# End Python code.
#
# An output console is shown with two output lines present, "Enter name of best friend:
# Marty McFly" and "My best friend is Marty McFly".
#
# Two memory spaces are shown, one empty and the other occupied with the value "Marty McFly" for variable best_friend.
#
# An input box is shown, occupied with the input "Marty McFly".
#
# Step 1: The input() statement gets an input value from the keyboard and puts that value into the best_friend variable.
# The Python code line, print("Enter name of best friend:", end=" ") executes. The text "Enter name of best friend:" is outputted to the output console. Next, the Python code line, best_friend = input() is executed. "Marty McFly" is inputted by the user and is assigned to the variable best_friend.

# %% [markdown]
# Step 2: best_friend's value can then be used in subsequent processing and outputs.
# The Python code line, print("My best friend is", best_friend)executes. The text, "My best friend is Marty McFly" is outputted to the output console.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Reading user input.
#
# **1.** What's the value of dog_name after the following code executes?

# %%
dog_name = input()

# %% [markdown]
# - Whatever value was entered by the user. ✓
# - dog_name is never assigned a value.
# *The program will wait for a user to type some input and press the return key. The provided input will be assigned as a new string to dog_name.*
#
# **2.** Which statement reads a user-entered string into variable num_cars?
# - `num_cars = input`
# - `input() = num_cars`
# - `num_cars = input()` ✓
# *The = means that the variable on the left gets assigned with the value on the right. The input() function will return the next string read from input, so num_cars will be assigned with that string.*

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Reading user input.
#
# **1.** Complete a statement that reads a user-entered string into variable my_var.
# Answer: my_var = input()
# *Hint: Use the input() function to read in a string. ? = input()*
# *input() reads in a string from the user, and then my_var is assigned with that string.*
#
# **2.** Write a program that accepts two unique user inputs. Assign the first input to variable x, and the second input to variable y. (Hint: you can use input() multiple times in a program).

# %% [markdown]
# **Answer:**

# %%
x = input()
y = input()

# %% [markdown]
# *Hint: Use the input() function to read in a string. ? = input(). You can use input() once for x, and once for y.*
# *input() will wait for a user to provide input each time it is used. You can use input() multiple times in a program if more than one input is needed.*

# %% [markdown]
# ### Converting input types
#
# The string "123" (with quotes) is fundamentally different from the integer 123 (without quotes). The "123" string is a sequence of the characters "1", "2", and "3" arranged in a certain order, whereas 123 represents the integer value one-hundred twenty-three. Strings and integers are each an example of a type; a type determines how a value can behave. For example, integers can be divided by 2, but not strings (what sense would `"Hello" / 2` make?). Types are discussed in detail later on.
#
#  Reading from input always results in a string type. However, often a programmer wants to read in an integer, and then use that number in a calculation. If a string contains only numbers, like "123", then the int() function can be used to convert that string to the integer 123.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Converting input to integers to perform calculations.
#
# Static Figure:
#
# Begin Python code:
# print("Enter wage:", end=" ")
# wage = int(input())
# new_wage = wage + 10
# print("New wage:", new_wage)
# End Python code.
#
# An output console is shown with two output lines present, "Enter wage: 8" and "New wage: 18".
# Two memory spaces are shown, one occupied with the value 8 for the variable wage, and the other occupied with the value 18 for the variable new_wage.
# An input box is shown, occupied with the input "8".
#
# Step 1: The Python code line, print("Enter wage:", end=" ") executes. The text "Enter wage: " is outputted to the output console. Next, The Python code line, wage = int(input()) is executed. "8" is inputted by the user and returned by the input() function.
# Step 2: The int() function then runs the "8" value returned by the input function as int("8"). The result is an integer value 8. The integer value 8 is assigned to the variable wage.
#
# Step 3: The Python code line, new_wage = wage + 10 executes. new_wage is assigned a value of 8 + 10 = 18. The Python code line, print("New wage:", new_wage) executes. The text "New wage: 18" is outputted to the output console.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Converting user input to integers.
#
# **1.** Type a statement that converts the string "15" to an integer and assigns my_var with the result.
# Answer: my_var = int('15') or my_var = int("15")
# *Hint: Use the int() function to convert "15" to an integer. my_var = ?. Don't forget quotes around "15".*
# *Input must be converted to an integer if using the input in a calculation.*
#
# new_var =

# %% [markdown]
# **2.**

# %%
my_var = int(input())

# %% [markdown]
# Answer: my_var + 5 or 5 + my_var
# *Hint: Perform the addition.*
# *To perform addition int() must be used to change the input string to an integer.*

# %% [markdown]
# ### Input prompt
#
# Adding a string inside the parentheses of input() displays a prompt to the user before waiting for input and is a useful shortcut to adding an additional print statement line.

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Basic input example.
#
# Static figure: A code block is shown, with an output box or console below it. To the right are three boxes to contain the values of the variables hours, weeks, and hourly_wage. Below the variable values is an Input box.
#
# Begin Python code:
# hours = 40
# weeks = 52
# hourly_wage = int(input("Enter hourly wage: "))
#
# print("Salary is", end=" ")
# print(hourly_wage * hours * weeks)
#
# Variables are:
# hours: 40
# weeks: 52
# hourly_wage: 41600
#
# Input is:
# 12
# 20
#
# Output is:
# Enter hourly wage: 12
# Salary is 24960
# …
# Enter hourly wage: 20
# Salary is 41600
#
# Step 1: The values for hours worked and weeks worked are stored in variables. The first line of code is highlighted, and the value 40 moves from the code window to the box for hours. The second line of code is highlighted, and the value 52 moves from the code window to the box for weeks.
#
# Step 2: input() prompts the user by printing Enter hourly wage and takes the value of the hourly wage from the user input. int() converts the value of the hourly wage to an integer. The third line of code is highlighted. The string "Enter hourly wage: " moves to the output box. The value 12 appears in the Input box and moves to the end of the first line in the output, and a cursor moves from the beginning of the line to after "12". The value 12 moves to the third line of code. Below the line of code, the expression int() appears, surrounds the value 12, and then 12 moves to the box for hourly_wage.
#
# Step 3: Salary is printed to the output. The value of end is an empty space. Thus, the output of the next print will be on the same line, separated by a single space. The fourth line of code is highlighted. The string "Salary is" moves to the output box, and a cursor moves from the beginning of the line to after "is". A single space from the end argument is highlighted in the line of code and moves to the output box, where the cursor moves one space to the right of "Salary is"..
#
# Step 4: The salary is the product of the variables hourly_wage, hours, and weeks. The salary prints on the same line because of the value of end in the previous line of code. The fifth line of code is highlighted. The values for hourly_wage, hours, and weeks move from the variable boxes to the expression within print(). Their product, 24960, appears to the right of the code, and moves to the same line in the output box as "Salary is ", and the cursor moves to the end of the line.

# %% [markdown]
# ### LAB ACTIVITY: Basic input.
#
# Run the program, enter 3 as input, and observe the output. Run the program again and enter another number as input.

# %% [markdown]
# ### CHALLENGE ACTIVITY: Read user input and print to output.
#
# The program reads integers user\_num1 and user\_num2 from input. Drag and drop the correct code statements to read integer user\_num3 from input, then output the product of user\_num1, user\_num2, and user\_num3.
#
# Ex: If the input is:
#
# `2`
#
# `3`
#
# `5`
#
# then the output is:
#
# `30`
#
# Note: Not all code statements on the left should be used in the final solution.

# %% [markdown]
# **Solution:**

# %%
user_num1 = int(input()) # Reads user_num1 from input
user_num2 = int(input()) # Reads user_num2 from input
user_num3 = int(input())

print(user_num1 * user_num2 * user_num3)

# %% [markdown]
# **Distractor lines (wrong answers):**
# - `int(input())`
# - `user_num3 = input()`
# - `user_num1 * user_num2 * user_num3`

# %% [markdown]
# ### CHALLENGE ACTIVITY: Input/Output. (5 Levels)

# %% [markdown]
# **Level 1:**

# %% [markdown]
# **Task:**
# This activity has randomized questions with unlimited attempts. You must pass all tests in a level before proceeding to the next level. The first level shows how the autograder works. Complete the following three steps:
# [...]
# Learn how our autograder works

# %% [markdown]
# **Explanation pattern:**
# Your code is tested with three random input values each time "Check" is clicked. For each test below, if your output matches the expected output, then the test passes. For the first test, [...] reads [...] from input into variable [...]. Then, [...] outputs "[...]", followed by a space, the value of [...] ([...]), and a newline. [...]

# %% [markdown]
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 2:**

# %% [markdown]
# **Task:**
# The following figure with [...] outputs the figure's first line. Complete the program with [...] statements to ensure the program's output matches the given figure exactly, including number of spaces and newlines. [...]

# %% [markdown]
# **Explanation pattern:**
# [...] Note: Since the program does not read from input, only one test is used to check if your code produces the correct output.

# %% [markdown]
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 3:**

# %% [markdown]
# **Task:**
# [...] In [...], separate the strings and variables with commas to automatically add a space character between each. Note: ends with a newline by default. [...]

# %% [markdown]
# **Explanation pattern:**
# [...] Note: If any of the tests did not pass, the output produced by your code is shown, followed by the expected output of the program. Any differences are highlighted in yellow.

# %% [markdown]
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 4:**
#
# *Task is dynamically generated (randomized each attempt).*

# %% [markdown]
# **Code structure:**

# %%
""" Your code goes here """
print(___)

# %% [markdown]
# **Level 5:**
#
# *Task is dynamically generated (randomized each attempt).*

# %% [markdown]
# **Code structure:**

# %%
""" Your code goes here """
