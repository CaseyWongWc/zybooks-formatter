# %% [markdown]
# <a href="https://colab.research.google.com/github/CaseyWongWc/zybooks-formatter/blob/main2/notebooks/CS_2520_Midterm_Practice_-_Handwritten_Prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 2520 Midterm Practice - Handwritten Prep
#
# **Instructions:** Read each problem, write your answer ON PAPER, then run the code cell below to check.
#
# **Covers:** Chapters 1-7 (Expressions, Types, Branches, Loops, Functions, Strings, Lists/Dicts)
#
# ---
#
# ## Section 1: What's the Output? (Trace by hand)
#
# For each snippet, write EXACTLY what gets printed.
#
# ### Problem 1: Expressions & Types (Ch 1-2)

# %%
x = 17
y = 5
print(x // y)
print(x % y)
print(x / y)
print(type(x / y))
print(type(x // y))

# %% [markdown]
# ```
# 3
# 2
# 3.4
# float
# int
# ```

# %% [markdown]
# ### Problem 2: String Formatting (Ch 2)

# %%
name = 'Alice'
age = 20
gpa = 3.14159

print(f'{name} is {age} years old')
print(f'GPA: {gpa:.2f}')
print(f'{name:>10}')
print(f'{name:<10}|')
print(f'{age:05d}')
# Out:
# Alice is 20 years old
# GPA: 3.14
#      Alice
# Alice     |
# 00020

# %% [markdown]
# ```
#  Alice is 20 years old
#  GPA: 3.14
#       Alice
# Alice
# ❌ i forgot
# ```

# %% [markdown]
# ### Problem 3: Type Conversions (Ch 3)

# %%
a = '5'
b = 2
print(int(a) + b)
print(a * b)
print(float(a) + b)
print(str(b) + a)
print(bool(0), bool(''), bool('hello'), bool(-1))
# Out:
# 7
# 55
# 7.0
# 25
# False False True True

# %% [markdown]
# ```
# 7
# ERROR
# 25
# ERROR
# ```

# %% [markdown]
# ### Problem 4: Branching / Conditionals (Ch 4)

# %%
score = 75
if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
else:
    grade = 'F'

print(grade)
print('Pass' if score >= 60 else 'Fail')
# Out:
# C
# Pass

# %% [markdown]
# ```
# B
# Pass
# ```

# %% [markdown]
# ### Problem 5: Loops (Ch 5)

# %%
total = 0
for i in range(1, 6):
    total += i
    if i == 3:
        continue
    print(i, end=' ')
print()
print('Total:', total)
# Out:
# 1 2 4 5
# Total: 15

# %% [markdown]
# ```
# 1
#
# 2
#
# 4
#
# 5
#
# Total:12
# ```

# %% [markdown]
# ### Problem 6: Nested Loops (Ch 5)

# %%
for i in range(3):
    for j in range(i + 1):
        print('*', end='')
    print()
# Out:
# *
# **
# ***

# %% [markdown]
# ```
# *
# **
# ***
# ```

# %% [markdown]
# ### Problem 7: While Loops (Ch 5)

# %%
x = 16
count = 0
while x > 1:
    x = x // 2
    count += 1
print(f'x={x}, count={count}')
# Out:
# x=1, count=4

# %% [markdown]
# ```
# x=1, count=4
# ```

# %% [markdown]
# ---
#
# ## Section 2: Write the Function (on paper!)
#
# Read the description, write the COMPLETE function on paper, then run the cell to check.
#
# ### Problem 8: Sum of evens
#
# Write a function `sum_evens(n)` that returns the sum of all even numbers from 2 to n (inclusive).
#
# Example: `sum_evens(6)` returns `12` (2+4+6)

# %%
# ANSWER - don't peek until you've written it!
def sum_evens(n):
    total = 0
    for i in range(2, n + 1, 2):
        total += i
    return total

# Test
print(sum_evens(6))   # 12
print(sum_evens(10))  # 30
print(sum_evens(1))   # 0

# %% [markdown]
# ### Problem 9: Count vowels
#
# Write a function `count_vowels(s)` that returns the number of vowels (a,e,i,o,u) in a string. Case insensitive.

# %%
# ANSWER - don't peek until you've written it!
def count_vowels(s):
    count = 0
    for ch in s.lower():
        if ch in 'aeiou':
            count += 1
    return count

# Test
print(count_vowels('Hello World'))  # 3
print(count_vowels('AEIOU'))        # 5
print(count_vowels('rhythm'))       # 0

# %% [markdown]
# ```
# def count_vowels(s):
#     s1 = list(s)
#     temp = 0
#     for x in s1:
#         if x == "a" or x == "e" or x == "i" or x == "o" or x == "u" or x == "A" or x == "E" or x == "I" or x == "O" or x == "U"
#         temp += 1
#     return temp
# ```
# https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/7761ad75-71b0-4b43-a56f-eca71aefe9bd

# %% [markdown]
# ### Problem 10: Reverse a string
#
# Write a function `reverse_str(s)` that returns the reversed string WITHOUT using slicing or reversed().

# %%
# ANSWER - don't peek until you've written it!
def reverse_str(s):
    result = ''
    for ch in s:
        result = ch + result
    return result

# Test
print(reverse_str('hello'))   # olleh
print(reverse_str('Python'))  # nohtyP
print(reverse_str(''))        # (empty)
# Out:
# olleh
# nohtyP

# %% [markdown]
# [0](https://myhelpyhand-imagedrop-2.replit.app/objects/uploads/69c36f8c-5653-4435-889b-6bfeefe146d6)
#
# caseys:
# ```
# def reverse_str(s):
#     a = s.split
#     b = []
#     while (a != []):
#         temp = a.pop()
#         b = b.append(temp)
#     return b
#
# ```
# corrected:
# ```
# def reverse_str(s):
#     a = list(s)
#     b = []
#     while a:          # cleaner than a != []
#         temp = a.pop()
#         b.append(temp)     # no b = !
#     return ''.join(b)
#
# ```

# %% [markdown]
# ---
#
# ## Section 3: Lists, Dicts, Tuples, Sets (Ch 6-7)
#
# ### Problem 11: List operations - trace output

# %%
nums = [10, 20, 30, 40, 50]
print(nums[1:4])
print(nums[-2:])
print(nums[::2])
nums.append(60)
nums.insert(0, 5)
print(nums)
print(len(nums))
# Out:
# [20, 30, 40]
# [40, 50]
# [10, 30, 50]
# [5, 10, 20, 30, 40, 50, 60]
# 7

# %% [markdown]
# casey
# ```
# [20,30,40,50]
# [10,20,30,40,50]
# [5,10,20,30,40,50,60]
# 7
# ```
# correted
# ```
# [20, 30, 40]       ← nums[1:4] is index 1,2,3 (4 is EXCLUSIVE)
# [40, 50]           ← nums[-2:] is last 2 elements
# [10, 30, 50]       ← nums[::2] is every other element (step 2)
# [5, 10, 20, 30, 40, 50, 60]
# 7
# ```

# %% [markdown]
# ### Problem 12: Dictionary operations

# %%
student = {'name': 'Bob', 'age': 21, 'gpa': 3.5}
print(student['name'])
print(student.get('major', 'Undeclared'))
student['major'] = 'CS'
print(len(student))
for key, val in student.items():
    print(f'{key}: {val}')
# Out:
# Bob
# Undeclared
# 4
# name: Bob
# age: 21
# gpa: 3.5
# major: CS

# %% [markdown]
# casey
# ```
# Bob
# Error
# 4
# name: Bob
# age: 21
# gpa: 3.5
# ```
# corrected:
# ```
# Bob
# Undeclared        ← .get() returns the default, no error!
# 4
# name: Bob
# age: 21
# gpa: 3.5
# major: CS         ← you forgot this one! major was added on line 4
#
# ```

# %% [markdown]
# ### Problem 13: Sets and Tuples

# %%
s1 = {1, 2, 3, 4}
s2 = {3, 4, 5, 6}
print(s1 & s2)
print(s1 | s2)
print(s1 - s2)

t = (10, 20, 30)
print(t[1])
# t[1] = 99  # What would happen? Write your answer!
# Out:
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# 20

# %% [markdown]
# ```
# {3,4}
# {1,2,3,4,5,6}
# {1,2,5,6}
# 20
# i think since its immutable an error would happen right?
# ```
#
# ```
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# 20
# ```

# %% [markdown]
# ### **waaw**

# %% [markdown]
# ### Problem 14: List comprehension

# %%
nums = [1, 2, 3, 4, 5, 6, 7, 8]
evens = [x for x in nums if x % 2 == 0]
squares = [x**2 for x in nums]
print(evens)
print(squares)
print([x for x in nums if x > 3 and x < 7])

# %% [markdown]
# ### Problem 15: Write a function with dicts
#
# Write a function `word_count(sentence)` that takes a string and returns a dict with each word as key and its count as value.
#
# Example: `word_count('the cat and the dog')` returns `{'the': 2, 'cat': 1, 'and': 1, 'dog': 1}`

# %%
# ANSWER - don't peek until you've written it!
def word_count(sentence):
    counts = {}
    for word in sentence.split():
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts

# Test
print(word_count('the cat and the dog'))
print(word_count('hello hello hello'))
print(word_count('one'))

# %% [markdown]
# ---
#
# ## Section 4: Tricky Gotchas (common exam mistakes)
#
# ### Problem 16: Mutable default & references

# %%
a = [1, 2, 3]
b = a
b.append(4)
print(a)
print(b)
print(a is b)

c = a[:]
c.append(5)
print(a)
print(c)
print(a is c)

# %% [markdown]
# ### Problem 17: Integer division gotcha

# %%
print(7 / 2)
print(7 // 2)
print(-7 // 2)
print(7 % -2)
print(round(2.5))
print(round(3.5))

# %% [markdown]
# ### Problem 18: String immutability

# %%
s = 'hello'
# s[0] = 'H'  # What happens? Write your answer!
s = s.upper()
print(s)
t = s.replace('L', 'r')
print(s)
print(t)
