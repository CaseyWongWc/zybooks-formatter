# %% [markdown]
# ## 7.1 String slicing
#
# ### String slicing basics
#
# Strings are a sequence type, having characters ordered by index from left to right. An index is an integer matching a specific position in a string's sequence of characters. An individual character is read using an index surrounded by brackets. Ex: `my_str[5]` reads the character at index 5 of the string `my_str`. Indices start at 0, so index 5 is a reference to the 6th character in the string.
#
# A programmer often needs to read more than one character at a time. Multiple consecutive characters can be read using slice notation. Slice notation has the form `my_str[start:end]`, which creates a new string whose value contains the characters of `my_str` from indices start to end -1. If `my_str` is "Boggle", then `my_str[0:3]` yields string  "Bog". Other sequence types like lists and tuples also support slice notation.
#
# > **String slicing.**
# >

# %%
> url = "http://en.wikipedia.org/wiki/Turing"
> domain = url[7:23]  # Read "en.wikipedia.org" from url
> print(domain)
>

# %% [markdown]
# >
# >

# %%
> en.wikipedia.org
>

# %% [markdown]
# The last character of the slice is one location *before* the specified end. Consider the string `my_str = "John Doe"`. The slice `my_str[0:4]` includes the element at index 0 (J), 1 (o), 2 (h), and 3 (n), but *not* 4, thus yielding "John". The space character at index 4 is not included. Similarly, `my_str[4:7]` would yield " Do", including the space character this time. To retrieve the last character, an end index greater than the length of the string can be used. Ex: `my_str[5:8]` or `my_str[5:10]` both yield the string "Doe".
#
# Negative numbers can be used to specify an index relative to the end of the string. Ex: If the variable `my_str` is "Jane Doe!?", then `my_str[0:-2]` yields "Jane Doe" because the -2 refers to the second-to-last character "!", and the character at the end index is not included in the result string.
#
# ### PARTICIPATION ACTIVITY: Slicing.
#
# Static Figure: A string variable my_str  is shown, with the contents of the string being "DO NOT LIE!". Each of the characters in the string are labeled with indexes 0 to 10.
#
# "D" is located at index 0. "O" is located at index 1. Index 2 is a blank space. "N" is located at index 3. "O" is located at index 4. "T" is located at index 5. Index 6 is a blank space. "L" is located at index 7. "I" is located at index 8. "E" is located at index 9. "!" is located at index 10.
#
# The indexes 7, 8, and 9 are highlighted. Below my_str, 3 substrings of my_str are shown.
#
# my_str[0:2] : "DO"
# my_str[0:6] : "DO NOT"
# my_str[7:10] : "LIE"
#
# Step 1: my_str[0:2] returns a substring of my_str starting at index 0 up to, but not including, index 2. The characters that start at index 0 up to, but don't include index 2 are "D" and "O", so the substring returns "DO".
#
# Step 2: my_str[0:6] returns a substring of my_str starting at index 0 up to, but not including, index 6. The characters that start at index 0 up to , but don't include index 6 are "D", "O", " ", "N", "O", and "T", with a blank space at index 2. The substring returns "DO NOT".
#
# Step 3: my_str[7:10] returns a substring of my_str starting at index 7 up to, but not including, index 10. The characters that start at index 7 up to, but not including index 10 are "L", "I", and "E". The substring returns "LIE".
#
# ### PARTICIPATION ACTIVITY: Slicing basics.
#
# **1.**

# %%
my_str = "The cat in the hat"
print(my_str[0:3])

# %% [markdown]
# Answer: The
# *Hint: The slice of my_str contains characters in positions 0, 1, and 2.*
# *The slice contains characters in positions 0, 1, and 2: "The".*
#
# **2.**

# %%
my_str = "The cat in the hat"
print(my_str[3:7])

# %% [markdown]
# Answer:  cat
# *Hint: The slice of my_str contains characters in positions 3, 4, 5, and 6.*
# *The slice includes the character in the start position, 3, as well as 4, 5, and 6. Those four characters are space, c, a, and t.*
#
# ### Slicing and slicing operations
#
# The Python interpreter creates a new string object for the slice. Thus, creating a slice of the string variable `my_str`, and then changing the value of `my_str`, does not also change the value of the slice.
#
# > **A slice creates a new object.**
# >

# %%
> my_str = "The cat jumped the brown cow"
> animal = my_str[4:7]
> print(f"The animal is a {animal}")
> 
> my_str = "The fox jumped the brown llama"
> print(f"The animal is still a {animal}")# animal variable remains unchanged.
>

# %% [markdown]
# >
# >
# >
# >
# >
# >

# %%
> The animal is a cat
> The animal is still a cat
>

# %% [markdown]
# A programmer often wants to read all characters that occur before or after some index in the string. Omitting a start index, such as in `my_str[:end]` yields the characters from indices 0 to end -1. Ex: `my_str[:5]` reads indices 0-4. Similarly, omitting the end index yields the characters from the start index to the end of the string.
# Ex: `my_str[5:]` yields all characters at and after index 5.
#
# Use the below tool to experiment with slice notation. After using positive values only, try entering negative start or end indices. Then try omitting either the start or end index.
#
# ### PARTICIPATION ACTIVITY: String slicing tool.
#
# Question: Provide values for (ANSWER FIELD A) and (ANSWER FIELD B) in the below code to observe the output.

# %%
string_var = "Hey folks!"
print(string_var[(ANSWER FIELD A): (ANSWER FIELD B)])

# %% [markdown]
# -
# Entering positive values such Answer A is less than Answer B prints a substring of string_var from index Answer A to index Answer B. For example, Answer A = 1 and Answer B = 5 prints "ey f".
#
# -
# Entering positive values such that Answer A is greater than Answer B will always print an empty string. For example, Answer A = 5 and Answer B = 1 prints "".
#
# Index -1 indicates the last character of the string, index -2 indicates the second to last character of the string, etc.
#
# -
# Entering negative values where Answer A is less than Answer B prints a substring of string_var from index Answer A to index Answer B. For example, Answer A = -5 and Answer B = -1 prints "olks".
#
#
# -
# Entering negative values where Answer A is greater than Answer B will always print an empty string. For example, Answer A = -5 and Answer B = -1 prints "".
#
# -
# Omitting the start position prints a substring of string_var from index 0 (the beginning of the string) to index Answer B. For example, Answer A = "" and Answer B = 5 prints "Hey f".
#
# -
# Omitting the end position prints a substring of string_var from index Answer A to the end to the string. For example, Answer A = 1 and Answer B = "" prints "ey folks!".
#
# Variables can also be used in place of literals to specify slice notation start and end indices. Ex: `my_str[x:y]`.
#
# ### LAB ACTIVITY: Slicing example: omitting start, end indices.
#
# Run the program below.
#
# Specifying a start index beyond the end of the string, or beyond the end index (like 3:2), yields an empty string. Ex: `my_str[2:1]` is ""'. Specifying an end index beyond the end of the string is equivalent to specifying the end of the string, so if a string's end is 5, then 1:7 or 1:99 are the same as 1:6.
#
# > **Common slicing operations.**
# > A list of common slicing operations a programmer might use.
# > Assume the value of my_str is "http://en.wikipedia.org/wiki/Nasa/"
# >
# > Syntax
# > Result
# > Description
# >
# > `my_str[10:19]`
# > wikipedia
# > Returns the characters in indices 10-18.
# >
# > `my_str[10:-5]`
# > wikipedia.org/wiki/
# > Returns the characters in indices 10-28.
# >
# > `my_str[8:]`
# > n.wikipedia.org/wiki/Nasa/
# >  Returns all characters from index 8 until the end of the string.
# >
# > `my_str[:23]`
# > http://en.wikipedia.org
# > Returns every character up to index 23, but not including my_str[23].
# >
# > `my_str[:-1]`
# > http://en.wikipedia.org/wiki/Nasa
# > Returns all but the last character.
#
# ### PARTICIPATION ACTIVITY: Slicing.
#
# **1.** What is the output?

# %%
my_str = "http://reddit.com/r/python"
print(my_str[17:])

# %% [markdown]
# Answer: /r/python
# *Hint: The 17th element is /, which is included in the result. Omitting the end position, read all characters from the start position until the string ends.*
# *The start position is the third / character in `my_str`. Since the end position is omitted, the slice reads the rest of the characters in the string.*
#
# **2.** What is the output?

# %%
my_str = "http://reddit.com/r/python"
protocol = "http://"
print(my_str[len(protocol):])

# %% [markdown]
# Answer: reddit.com/r/python
# *Hint: len(protocol) is 7, thus the slicing operation is `my_str[7:]`*
# *len(protocol) is 7, thus the slicing operation is `my_str[7:]`, which reads the entire string excluding the first seven characters.*
#
# ### The slice stride
#
# Slice notation also provides for a third argument known as the stride. The stride determines how much to increment the index after reading each element. For example, `my_str[0:10:2]` reads every other element between 0 and 10. The stride defaults to 1 if not specified.
#
# > **Slice stride.**
# >

# %%
> numbers = "0123456789"
> 
> print(f"All numbers: {numbers[::]}")
> print(f"Every even number: {numbers[::2]}")
> print(f"Every third number between 1 and 8: {numbers[1:9:3]}")
>

# %% [markdown]
# >
# >

# %%
> All numbers: 0123456789
> Every even number: 02468
> Every third number between 1 and 8: 147
>

# %% [markdown]
# ### PARTICIPATION ACTIVITY: Slice stride.
#
# **1.** What is the output?

# %%
my_str = "Agt2t3afc2kjMhagrds!"
print(my_str[0:5:1])

# %% [markdown]
# Answer: Agt2t
# *Hint: The first 5 characters*
# *Reads the first 5 characters, adding a stride of 1 to the index to find each new element to read*
#
# **2.** What is the output?

# %%
my_str = "Agt2t3afc2kjMhagrds!"
print(my_str[::2])

# %% [markdown]
# Answer: AttackMars
# *Hint: Reads every other character, starting with the first character.*
# *Reads every other character because the stride is 2.*
#
# ### CHALLENGE ACTIVITY: Enter the output of the sliced string.
#
# **Level 1:**
#
# What is the output?

# %%
state = "Florida"
state_slice = state[0:2]
print(state_slice)

# %% [markdown]
# *`state[0:2]` creates a new string whose value yields the characters of state from indices 0 to 1 (2 - 1), so from "F" to "l".*
#
# **Level 2:**
#
# What is the output?

# %%
state = "Florida"
state_slice = state[:2]
print(state_slice)

# %% [markdown]
# *Omitting a start index, such as in `state[:2]`, yields the characters from indices 0 to 1 (2 - 1), so from "F" to "l".*
#
# **Level 3:**
#
# What is the output?

# %%
state = "Florida"
my_slice = state[1:2]
print(my_slice)

# %% [markdown]
# *`state[1:2]` yields the characters in state from indices 1 to  1 (2 - 1), so from "l" to "l".*
#
# **Level 4:**
#
# What is the output?

# %%
state = "Florida"
my_slice = state[0:4:2]
print(my_slice)

# %% [markdown]
# *`state[0:4:2]` yields every second element of state from indices 0 to  3 (4 - 1).
# Thus state[0] and state[2] are returned, so "F" and "o".*
#
# **Level 5:**
#
# What is the output?

# %%
state = "Florida"
my_slice = state[0:-5]
print(my_slice)

# %% [markdown]
# *`state[0:-5]` yields the characters from indices 0 to -5.
# -5 refers to the fifth-from-last character "o", which is at index 2.
# `state[0:-5]` reads from indices 0 to 1 (2 - 1), so from "F" to "l".
# Note that the character at the end index is not included in the result string.*
#
# **Level 6:**
#
# What is the output?

# %%
state = "Florida"
my_slice = state[1:2]
print(my_slice)

state = "Idaho"
print(my_slice)

# %% [markdown]
# *Creating a slice of the string variable state, and then changing the value of state does not also change the value of the slice.*
#
# ### CHALLENGE ACTIVITY: String slicing. (4 Levels)
#
# **Level 1:**
#
# **Task pattern:**
# [...]
#
# **Explanation pattern:**
# Slice notation has the form [...][start:end], and creates a new string whose value contains the characters of [...] from indices start to end - 1. - Omitting the start index is the same as starting from index 0.
# - Omitting the end index is the same as ending at the end of the string. Thus, [...][0:end] and [...][:] both contain the characters of full_string from indices 0 to end - 1. [...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# **Level 2:**
#
# **Task pattern:**
# String [...] is read from input. [...]
#
# **Explanation pattern:**
# In slice notation, the start index is inclusive and the end index is exclusive. If the start index is 0, then 0 may be omitted from the slice notation. Negative numbers are used to specify an index relative to the end of the string. The index -1 yields the last character of the string, -2 yields the second to last character, and so on. Ex: If [...] is: `[example_input]` [...]
#
# **Code structure:**

# %%
___ = input()
""" Your code goes here """
print(___)

# %% [markdown]
# **Level 3:**
#
# **Task pattern:**
# String [...] is read from input. [...]
#
# **Explanation pattern:**
# String [...] is sliced twice. The first slice starts from the beginning of [...] to index [...], exclusive. The second slice starts from index [...], inclusive, to the end of [...]. Then, [...] is assigned with the concatenation of the two slices. As a result, [...]'s [...] [...]. Ex: For input[...]the first slice is [...][[...]] with characters from index 0, up to, but not including [...]. The second slice is [...][[...]] with characters from [...], up to the end of the string. Thus, the output is[...]
#
# **Code structure:**

# %%
___ = input()
""" Your code goes here """
print(___)

# %% [markdown]
# **Level 4:**
#
# **Task pattern:**
# [...]
#
# **Explanation pattern:**
# Slice notation has the form [...][start:end:stride] and provides for a third argument known as the stride. The stride determines how much to increment the index after reading each element. The stride defaults to 1 if not specified. [...]
#
# **Code structure:**

# %%
""" Your code goes here """

# %% [markdown]
# ---
# _API Debug: 22 resources fetched. Types: html(10), container(4), custom(4), short_answer(3), zystudio(1)_
